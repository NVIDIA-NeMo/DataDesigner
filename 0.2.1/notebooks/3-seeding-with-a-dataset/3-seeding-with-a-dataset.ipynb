# %% [markdown]
# # 🎨 Data Designer Tutorial: Seeding Synthetic Data Generation with an External Dataset
#
# #### 📚 What you'll learn
#
# In this notebook, we will demonstrate how to seed synthetic data generation in Data Designer with an external dataset.
#
# If this is your first time using Data Designer, we recommend starting with the [first notebook](https://nvidia-nemo.github.io/DataDesigner/latest/notebooks/1-the-basics/) in this tutorial series.

# %% [markdown]
# ### 📦 Import the essentials
#
# - The `essentials` module provides quick access to the most commonly used objects.

# %%
from data_designer.essentials import (
    ChatCompletionInferenceParams,
    DataDesigner,
    DataDesignerConfigBuilder,
    ModelConfig,
)

# %% [markdown]
# ### ⚙️ Initialize the Data Designer interface
#
# - `DataDesigner` is the main object is responsible for managing the data generation process.
#
# - When initialized without arguments, the [default model providers](https://nvidia-nemo.github.io/DataDesigner/latest/concepts/models/default-model-settings/) are used.

# %%
data_designer = DataDesigner()

# %% [markdown]
# ### 🎛️ Define model configurations
#
# - Each `ModelConfig` defines a model that can be used during the generation process.
#
# - The "model alias" is used to reference the model in the Data Designer config (as we will see below).
#
# - The "model provider" is the external service that hosts the model (see the [model config](https://nvidia-nemo.github.io/DataDesigner/latest/concepts/models/default-model-settings/) docs for more details).
#
# - By default, we use [build.nvidia.com](https://build.nvidia.com/models) as the model provider.

# %%
# This name is set in the model provider configuration.
MODEL_PROVIDER = "nvidia"

# The model ID is from build.nvidia.com.
MODEL_ID = "nvidia/nemotron-3-nano-30b-a3b"

# We choose this alias to be descriptive for our use case.
MODEL_ALIAS = "nemotron-nano-v3"

model_configs = [
    ModelConfig(
        alias=MODEL_ALIAS,
        model=MODEL_ID,
        provider=MODEL_PROVIDER,
        inference_parameters=ChatCompletionInferenceParams(
            temperature=1.0,
            top_p=1.0,
            max_tokens=2048,
            extra_body={"chat_template_kwargs": {"enable_thinking": False}},
        ),
    )
]

# %% [markdown]
# ### 🏗️ Initialize the Data Designer Config Builder
#
# - The Data Designer config defines the dataset schema and generation process.
#
# - The config builder provides an intuitive interface for building this configuration.
#
# - The list of model configs is provided to the builder at initialization.

# %%
config_builder = DataDesignerConfigBuilder(model_configs=model_configs)

# %% [markdown]
# ## 🏥 Prepare a seed dataset
#
# - For this notebook, we'll create a synthetic dataset of patient notes.
#
# - We will _seed_ the generation process with a [symptom-to-diagnosis dataset](https://huggingface.co/datasets/gretelai/symptom_to_diagnosis).
#
# - We already have the dataset downloaded in the [data](../data) directory of this repository.
#
# <br>
#
# > 🌱 **Why use a seed dataset?**
# >
# > - Seed datasets let you steer the generation process by providing context that is specific to your use case.
# >
# > - Seed datasets are also an excellent way to inject real-world diversity into your synthetic data.
# >
# > - During generation, prompt templates can reference any of the seed dataset fields.

# %%
# Download sample dataset from Github
import urllib.request

url = "https://raw.githubusercontent.com/NVIDIA/GenerativeAIExamples/refs/heads/main/nemo/NeMo-Data-Designer/data/gretelai_symptom_to_diagnosis.csv"
local_filename, _ = urllib.request.urlretrieve(url, "gretelai_symptom_to_diagnosis.csv")

# Seed datasets are passed as reference objects to the config builder.
seed_dataset_reference = data_designer.make_seed_reference_from_file(local_filename)

config_builder.with_seed_dataset(seed_dataset_reference)
# Out:
# DataDesignerConfigBuilder(
#     seed_dataset: 'gretelai_symptom_to_diagnosis.csv'
#     seed_dataset_columns: ['diagnosis', 'patient_summary']
# )

# %% [markdown]
# ## 🎨 Designing our synthetic patient notes dataset
#
# - Here we use `add_column` with keyword arguments (rather than imported config objects).
#
# - Generally, we recommend using concrete objects, but this is a convenient shorthand.
#
# - **Note**: The prompt template can reference fields from our seed dataset:
#   - `{{ diagnosis }}` - the medical diagnosis from the seed data
#   - `{{ patient_summary }}` - the symptom description from the seed data

# %%
config_builder.add_column(
    name="patient_sampler",
    column_type="sampler",
    sampler_type="person_from_faker",
)

config_builder.add_column(
    name="doctor_sampler",
    column_type="sampler",
    sampler_type="person_from_faker",
)

config_builder.add_column(
    name="patient_id",
    column_type="sampler",
    sampler_type="uuid",
    params={
        "prefix": "PT-",
        "short_form": True,
        "uppercase": True,
    },
)

config_builder.add_column(
    name="first_name",
    column_type="expression",
    expr="{{ patient_sampler.first_name}}",
)

config_builder.add_column(
    name="last_name",
    column_type="expression",
    expr="{{ patient_sampler.last_name }}",
)


config_builder.add_column(
    name="dob",
    column_type="expression",
    expr="{{ patient_sampler.birth_date }}",
)

config_builder.add_column(
    name="symptom_onset_date",
    column_type="sampler",
    sampler_type="datetime",
    params={"start": "2024-01-01", "end": "2024-12-31"},
)

config_builder.add_column(
    name="date_of_visit",
    column_type="sampler",
    sampler_type="timedelta",
    params={"dt_min": 1, "dt_max": 30, "reference_column_name": "symptom_onset_date"},
)

config_builder.add_column(
    name="physician",
    column_type="expression",
    expr="Dr. {{ doctor_sampler.last_name }}",
)

config_builder.add_column(
    name="physician_notes",
    column_type="llm-text",
    prompt="""\
You are a primary-care physician who just had an appointment with {{ first_name }} {{ last_name }},
who has been struggling with symptoms from {{ diagnosis }} since {{ symptom_onset_date }}.
The date of today's visit is {{ date_of_visit }}.

{{ patient_summary }}

Write careful notes about your visit with {{ first_name }},
as Dr. {{ doctor_sampler.first_name }} {{ doctor_sampler.last_name }}.

Format the notes as a busy doctor might.
Respond with only the notes, no other text.
""",
    model_alias=MODEL_ALIAS,
)

config_builder.validate()
# Out:
# [01:57:28] [INFO] ✅ Validation passed
# DataDesignerConfigBuilder(
#     seed_dataset: 'gretelai_symptom_to_diagnosis.csv'
#     seed_dataset_columns: ['diagnosis', 'patient_summary']
#     sampler_columns: [
#         "patient_sampler",
#         "doctor_sampler",
#         "patient_id",
#         "symptom_onset_date",
#         "date_of_visit"
#     ]
#     llm_text_columns: ['physician_notes']
#     expression_columns: [
#         "first_name",
#         "last_name",
#         "dob",
#         "physician"
#     ]
# )

# %% [markdown]
# ### 🔁 Iteration is key – preview the dataset!
#
# 1. Use the `preview` method to generate a sample of records quickly.
#
# 2. Inspect the results for quality and format issues.
#
# 3. Adjust column configurations, prompts, or parameters as needed.
#
# 4. Re-run the preview until satisfied.

# %%
preview = data_designer.preview(config_builder, num_records=2)
# Out:
# [01:57:28] [INFO] 🔭 Preview generation in progress
# [01:57:28] [INFO] ✅ Validation passed
# [01:57:28] [INFO] ⛓️ Sorting column configs into a Directed Acyclic Graph
# [01:57:28] [INFO] 🩺 Running health checks for models...
# [01:57:28] [INFO]   |-- 👀 Checking 'nvidia/nemotron-3-nano-30b-a3b' in provider named 'nvidia' for model alias 'nemotron-nano-v3'...
# [01:57:28] [INFO]   |-- ✅ Passed!
# [01:57:28] [INFO] 🌱 Sampling 2 records from seed dataset
# [01:57:28] [INFO]   |-- seed dataset size: 820 records
# [01:57:28] [INFO]   |-- sampling strategy: ordered
# [01:57:28] [INFO] 🎲 Preparing samplers to generate 2 records across 5 columns
# [01:57:28] [INFO] (💾 + 💾) Concatenating 2 datasets
# [01:57:28] [INFO] 🧩 Generating column `first_name` from expression
# [01:57:28] [INFO] 🧩 Generating column `last_name` from expression
# [01:57:28] [INFO] 🧩 Generating column `dob` from expression
# [01:57:28] [INFO] 🧩 Generating column `physician` from expression
# [01:57:28] [INFO] 📝 Preparing llm-text column generation
# [01:57:28] [INFO]   |-- column name: 'physician_notes'
# [01:57:28] [INFO]   |-- model config:
# {
#     "alias": "nemotron-nano-v3",
#     "model": "nvidia/nemotron-3-nano-30b-a3b",
#     "inference_parameters": {
#         "generation_type": "chat-completion",
#         "max_parallel_requests": 4,
#         "timeout": null,
#         "extra_body": {
#             "chat_template_kwargs": {
#                 "enable_thinking": false
#             }
#         },
#         "temperature": 1.0,
#         "top_p": 1.0,
#         "max_tokens": 2048
#     },
#     "provider": "nvidia"
# }
# [01:57:28] [INFO] 🐙 Processing llm-text column 'physician_notes' with 4 concurrent workers
# [01:57:38] [INFO] 📊 Model usage summary:
# {
#     "nvidia/nemotron-3-nano-30b-a3b": {
#         "token_usage": {
#             "input_tokens": 269,
#             "output_tokens": 2858,
#             "total_tokens": 3127
#         },
#         "request_usage": {
#             "successful_requests": 2,
#             "failed_requests": 0,
#             "total_requests": 2
#         },
#         "tokens_per_second": 318,
#         "requests_per_minute": 12
#     }
# }
# [01:57:38] [INFO] 📐 Measuring dataset column statistics:
# [01:57:38] [INFO]   |-- 🌱 column: 'diagnosis'
# [01:57:38] [INFO]   |-- 🌱 column: 'patient_summary'
# [01:57:38] [INFO]   |-- 🎲 column: 'patient_sampler'
# [01:57:38] [INFO]   |-- 🎲 column: 'doctor_sampler'
# [01:57:38] [INFO]   |-- 🎲 column: 'patient_id'
# [01:57:38] [INFO]   |-- 🧩 column: 'first_name'
# [01:57:38] [INFO]   |-- 🧩 column: 'last_name'
# [01:57:38] [INFO]   |-- 🧩 column: 'dob'
# [01:57:38] [INFO]   |-- 🎲 column: 'symptom_onset_date'
# [01:57:38] [INFO]   |-- 🎲 column: 'date_of_visit'
# [01:57:38] [INFO]   |-- 🧩 column: 'physician'
# [01:57:38] [INFO]   |-- 📝 column: 'physician_notes'
# [01:57:38] [INFO] 🎊 Preview complete!

# %%
# Run this cell multiple times to cycle through the 2 preview records.
preview.display_sample_record()
# Out:
#
#                                                    Seed Columns
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name            ┃ Value                                                                                         ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ diagnosis       │ cervical spondylosis                                                                          │
# ├─────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ patient_summary │ I've been having a lot of pain in my neck and back. I've also been having trouble with my     │
# │                 │ balance and coordination. I've been coughing a lot and my limbs feel weak.                    │
# └─────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────┘
#
#
#                                                  Generated Columns
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name               ┃ Value                                                                                      ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ patient_sampler    │ {                                                                                          │
# │                    │     'uuid': '6828e51b-4436-4943-a2cf-53a8ae70e857',                                        │
# │                    │     'locale': 'en_US',                                                                     │
# │                    │     'first_name': 'Terri',                                                                 │
# │                    │     'last_name': 'Miller',                                                                 │
# │                    │     'middle_name': None,                                                                   │
# │                    │     'sex': 'Female',                                                                       │
# │                    │     'street_number': '3623',                                                               │
# │                    │     'street_name': 'Vincent Islands',                                                      │
# │                    │     'city': 'Port John',                                                                   │
# │                    │     'state': 'Kentucky',                                                                   │
# │                    │     'postcode': '11115',                                                                   │
# │                    │     'age': 39,                                                                             │
# │                    │     'birth_date': '1986-01-11',                                                            │
# │                    │     'country': 'Libyan Arab Jamahiriya',                                                   │
# │                    │     'marital_status': 'married_present',                                                   │
# │                    │     'education_level': 'secondary_education',                                              │
# │                    │     'unit': '',                                                                            │
# │                    │     'occupation': 'Marketing executive',                                                   │
# │                    │     'phone_number': '378.787.3838',                                                        │
# │                    │     'bachelors_field': 'no_degree'                                                         │
# │                    │ }                                                                                          │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ doctor_sampler     │ {                                                                                          │
# │                    │     'uuid': 'e6a1773a-3686-41dd-853d-a45c21a5a534',                                        │
# │                    │     'locale': 'en_US',                                                                     │
# │                    │     'first_name': 'David',                                                                 │
# │                    │     'last_name': 'Ryan',                                                                   │
# │                    │     'middle_name': None,                                                                   │
# │                    │     'sex': 'Male',                                                                         │
# │                    │     'street_number': '01272',                                                              │
# │                    │     'street_name': 'Alexander Village',                                                    │
# │                    │     'city': 'Jeffreyfort',                                                                 │
# │                    │     'state': 'Louisiana',                                                                  │
# │                    │     'postcode': '23328',                                                                   │
# │                    │     'age': 18,                                                                             │
# │                    │     'birth_date': '2007-09-02',                                                            │
# │                    │     'country': 'Uzbekistan',                                                               │
# │                    │     'marital_status': 'never_married',                                                     │
# │                    │     'education_level': 'graduate',                                                         │
# │                    │     'unit': '',                                                                            │
# │                    │     'occupation': 'Haematologist',                                                         │
# │                    │     'phone_number': '417.904.8075x4317',                                                   │
# │                    │     'bachelors_field': 'education'                                                         │
# │                    │ }                                                                                          │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ patient_id         │ PT-BC73F6DB                                                                                │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ symptom_onset_date │ 2024                                                                                       │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ date_of_visit      │ 2024                                                                                       │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ first_name         │ Terri                                                                                      │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ last_name          │ Miller                                                                                     │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ dob                │ 1986-01-11                                                                                 │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ physician          │ Dr. Ryan                                                                                   │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ physician_notes    │ **Visit Note – Terri Miller – 2024‑04‑14**                                                 │
# │                    │                                                                                            │
# │                    │ - **Chief Complaint:** "Neck and back pain, balance problems, frequent coughing, weakness  │
# │                    │ in limbs."                                                                                 │
# │                    │ - **History of Present Illness (HPI):**                                                    │
# │                    │   - 9‑month worsening neck/back pain (Cervical spondylosis; exacerbates with extension)    │
# │                    │   - New onset gait instability, frequent near‑falls                                        │
# │                    │   - Bilateral lower‑extremity weakness (gradual, no trauma)                                │
# │                    │   - Chronic dry cough (non‑productive, increased with exertion)                            │
# │                    │   - No recent infections, fever, or weight loss                                            │
# │                    │   - Reports occasional numbness in hands, but no radicular pain                            │
# │                    │ - **Past Medical History (PMH):**                                                          │
# │                    │   - Cervical spondylosis diagnosed 2023; on PT/NSAIDs                                      │
# │                    │   - Hypertension, controlled with lisinopril                                               │
# │                    │   - No prior surgeries                                                                     │
# │                    │ - **Medications:** Lisinopril 20 mg daily; occasional ibuprofen 600 mg PRN                 │
# │                    │ - **Allergies:** NKDA                                                                      │
# │                    │ - **Family History:** Mother – osteoarthritis; Father – stroke at 68                       │
# │                    │ - **Social History:**                                                                      │
# │                    │   - Former smoker (15 pack‑years, quit 5 y ago)                                            │
# │                    │   - Alcohol: 1–2 drinks/week                                                               │
# │                    │   - Lives alone; independent ADLs                                                          │
# │                    │ - **Review of Systems (pertinent):**                                                       │
# │                    │   - Neurologic: gait instability, weakness, occasional paresthesias                        │
# │                    │   - Respiratory: chronic cough, no dyspnea at rest                                         │
# │                    │   - Musculoskeletal: neck/back pain, stiffness                                             │
# │                    │ - **Vitals:**                                                                              │
# │                    │   - BP 138/84 mm Hg                                                                        │
# │                    │   - HR 78 bpm                                                                              │
# │                    │   - RR 16/min                                                                              │
# │                    │   - Temp 98.4°F                                                                            │
# │                    │   - SpO₂ 97% RA                                                                            │
# │                    │   - Weight 165 lb, BMI 27 kg/m²                                                            │
# │                    │ - **Physical Exam:**                                                                       │
# │                    │   - **General:** Alert, oriented x3, in mild discomfort                                    │
# │                    │   - **HEENT:** No meningeal signs                                                          │
# │                    │   - **Neck:** Limited flexion/extension due to pain; mild crepitus; no palpable masses     │
# │                    │   - **Cardiovascular:** Regular rate/rhythm, no murmurs                                    │
# │                    │   - **Respiratory:** Clear to auscultation bilaterally; mild bibasilar crackles noted      │
# │                    │   - **Neurologic:**                                                                        │
# │                    │     - Cranial nerves II–XII intact                                                         │
# │                    │     - Strength: 4/5 in proximal upper extremities, 4/5 in proximal lower extremities; 5/5  │
# │                    │ distal                                                                                     │
# │                    │     - Reflexes: 2+ throughout; no planter response                                         │
# │                    │     - Coordination: Dysmetria on finger‑nose and heel‑shin tests                           │
# │                    │     - Gait: Wide‑based, requires assistance; tandem walking not possible                   │
# │                    │   - **Musculoskeletal:** No joint swelling; mild paraspinal tenderness                     │
# │                    │ - **Diagnostic Studies (ordered/considered):**                                             │
# │                    │   - Cervical MRI (cervical spine) – pending                                                │
# │                    │   - Lumbar spine MRI – pending (if lower‑extremity weakness progresses)                    │
# │                    │   - EMG/NCS – if focal weakness expands                                                    │
# │                    │   - Chest X‑ray – rule out chronic bronchitis/other lung pathology                         │
# │                    │   - Lab: CBC, CMP, TSH, ESR/CRP                                                            │
# │                    │ - **Assessment / Differential:**                                                           │
# │                    │   1. **Cervical spondylosis (multilevel) with progressive spinal canal stenosis →          │
# │                    │ myelopathic signs (balance, gait, weakness).**                                             │
# │                    │   2. **Possible early normal‑pressure hydrocephalus (gait disturbance + mild urinary       │
# │                    │ frequency? – not yet documented).**                                                        │
# │                    │   3. **Chronic bronchitis or other pulmonary etiology of cough (smoking history).**        │
# │                    │   4. **Degenerative myopathy vs peripheral neuropathy (needs EMG/NCS).**                   │
# │                    │   5. **Hypertension‑related cerebrovascular disease – low suspicion given gradual onset.** │
# │                    │ - **Plan:**                                                                                │
# │                    │   - **Imaging:** Schedule cervical spine MRI (outpatient imaging center) within 1 week;    │
# │                    │ obtain lumbar MRI if cervical findings significant.                                        │
# │                    │   - **Medication:** Continue ibuprofen 600 mg TID PRN for pain; consider switching to      │
# │                    │ acetaminophen if renal concerns arise.                                                     │
# │                    │   - **Referral:**                                                                          │
# │                    │     - Physical therapy focusing on gait training, neck stabilization, and cervical         │
# │                    │ proprioceptive exercises.                                                                  │
# │                    │     - Neurology consult for formal assessment of myelopathy and to discuss potential       │
# │                    │ surgical options (e.g., anterior cervical discectomy & fusion) if MRI shows significant    │
# │                    │ canal compromise.                                                                          │
# │                    │   - **Monitor:**                                                                           │
# │                    │     - Monitor for new urinary urgency, worsening weakness, or falls.                       │
# │                    │     - Re‑evaluate cough; schedule follow‑up with pulmonology if persistent >8 weeks.       │
# │                    │   - **Lifestyle:**                                                                         │
# │                    │     - Encourage regular low‑impact aerobic activity (e.g., stationary cycling) to maintain │
# │                    │ conditioning.                                                                              │
# │                    │     - Smoking cessation reinforcement; offer resources.                                    │
# │                    │   - **Follow‑up:** Return visit in 2 weeks after imaging results reviewed, or sooner if    │
# │                    │ symptoms acutely worsen (e.g., severe weakness, new bowel/bladder changes).                │
# │                    │ - **Patient Education:**                                                                   │
# │                    │   - Discussed the nature of cervical spondylosis and how degenerative changes can compress │
# │                    │ neural structures.                                                                         │
# │                    │   - Reviewed signs of worsening myelopathy (increasing weakness, gait instability, loss of │
# │                    │ bladder control) and advised immediate ED presentation if they occur.                      │
# │                    │   - Instructed on proper body mechanics for neck protection (avoid prolonged neck          │
# │                    │ extension, use supportive pillow).                                                         │
# │                    │   - Provided printed PT exercise handout.                                                  │
# │                    │                                                                                            │
# │                    │ **Signature:**                                                                             │
# │                    │ *Dr. David Ryan, MD*                                                                       │
# │                    │ Internal Medicine / Neurology (consult)                                                    │
# │                    │ Date: 2024‑04‑14                                                                           │
# │                    │ </think>                                                                                   │
# │                    │ **Visit Note – Terri Miller – 2024‑04‑14**                                                 │
# │                    │                                                                                            │
# │                    │ - **CC:** “Neck and back pain, balance problems, frequent coughing, weakness in limbs.”    │
# │                    │ - **HPI:** 9 mo worsening neck/back pain (cervical spondylosis); new gait                  │
# │                    │ instability/near‑falls; bilateral lower‑extremity weakness (gradual); chronic dry cough;   │
# │                    │ occasional hand numbness; no fever, weight loss, or trauma.                                │
# │                    │ - **PMH:** Cervical spondylosis (dx 2023) – PT/NSAIDs; HTN, controlled on lisinopril; no   │
# │                    │ surgeries.                                                                                 │
# │                    │ - **Medications:** Lisinopril 20 mg daily; ibuprofen 600 mg PRN.                           │
# │                    │ - **Allergies:** NKDA.                                                                     │
# │                    │ - **FH:** Mother – osteoarthritis; Father – stroke @68.                                    │
# │                    │ - **SH:** Former smoker (15 pack‑yr, quit 5 y ago); alcohol 1‑2 drinks/wk; lives alone;    │
# │                    │ independent ADLs.                                                                          │
# │                    │ - **ROS:** Neuro – gait instability, weakness, paresthesias; Respiratory – chronic cough;  │
# │                    │ MSK – neck/back pain/stiffness.                                                            │
# │                    │ - **Vitals:** BP 138/84 mmHg; HR 78; RR 16; Temp 98.4 °F; SpO₂ 97% RA; Wt 165 lb; BMI 27   │
# │                    │ kg/m².                                                                                     │
# │                    │ - **PE:**                                                                                  │
# │                    │   - General: Alert AO ×3, mild discomfort.                                                 │
# │                    │   - Neuro: CN II‑XII intact; Strength 4/5 proximal UE/LE; 5/5 distal; Reflexes 2+;         │
# │                    │ Coordination dysmetria (finger‑nose, heel‑shin); Gait wide‑based, requires assistance;     │
# │                    │ tandem walking impossible.                                                                 │
# │                    │   - Musculoskeletal: Limited neck ROM (painful extension), mild paraspinal tenderness; no  │
# │                    │ joint swelling.                                                                            │
# │                    │   - Respiratory: Clear lungs, mild bibasilar crackles.                                     │
# │                    │ - **Assessment/Ddx:**                                                                      │
# │                    │   1. Multilevel cervical spondylosis with progressive canal stenosis → myelopathic signs   │
# │                    │ (balance, weakness).                                                                       │
# │                    │   2. Consider normal‑pressure hydrocephalus (gait disturbance).                            │
# │                    │   3. Chronic bronchitis/pulmonary etiology for cough.                                      │
# │                    │   4. Degenerative myopathy vs peripheral neuropathy (needs EMG/NCS).                       │
# │                    │   5. Low suspicion for acute cerebrovascular event.                                        │
# │                    │ - **Plan:**                                                                                │
# │                    │   - **Imaging:** Order cervical MRI (outpatient imaging) within 7 days; lumbar MRI if      │
# │                    │ cervical findings significant; consider EMG/NCS if weakness expands.                       │
# │                    │   - **Labs:** CBC, CMP, TSH, ESR/CRP.                                                      │
# │                    │   - **Med:** Continue ibuprofen 600 mg TID PRN; switch to acetaminophen if renal concerns  │
# │                    │ arise.                                                                                     │
# │                    │   - **Referrals:**                                                                         │
# │                    │     - PT – gait training, cervical stabilization, proprioceptive exercises.                │
# │                    │     - Neurology – formal myelopathy eval, discuss possible surgical intervention (e.g.,    │
# │                    │ AC‑fusion) if MRI shows meaningful stenosis.                                               │
# │                    │   - **Monitoring:** Watch for new urinary urgency, worsening weakness, falls; persistent   │
# │                    │ cough >8 wks → pulmonology referral.                                                       │
# │                    │   - **Lifestyle:** Low‑impact aerobic                                                      │
# └────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────┘
#
#                                                     [index: 0]

# %%
# The preview dataset is available as a pandas DataFrame.
preview.dataset
# Out:
#               diagnosis                                    patient_summary  \
# 0  cervical spondylosis  I've been having a lot of pain in my neck and ...
# 1              impetigo  I have a rash on my face that is getting worse...
#
#                                      patient_sampler  \
# 0  {'uuid': '6828e51b-4436-4943-a2cf-53a8ae70e857...
# 1  {'uuid': '7ef7b85f-8f82-449c-af1d-e47aab5e2a66...
#
#                                       doctor_sampler   patient_id  \
# 0  {'uuid': 'e6a1773a-3686-41dd-853d-a45c21a5a534...  PT-BC73F6DB
# 1  {'uuid': '7cc410f9-9e48-4ef5-aaed-2f123eee1234...  PT-53916EAD
#
#   symptom_onset_date date_of_visit first_name last_name         dob  \
# 0               2024          2024      Terri    Miller  1986-01-11
# 1               2024          2024    Vincent     Clark  1937-04-17
#
#     physician                                    physician_notes
# 0    Dr. Ryan  **Visit Note – Terri Miller – 2024‑04‑14**\n\n...
# 1  Dr. Wright  V. Clark – 45M – Impetigo exacerbation (face) ...

# %% [markdown]
# ### 📊 Analyze the generated data
#
# - Data Designer automatically generates a basic statistical analysis of the generated data.
#
# - This analysis is available via the `analysis` property of generation result objects.

# %%
# Print the analysis as a table.
preview.analysis.to_report()
# Out:
# ──────────────────────────────────────── 🎨 Data Designer Dataset Profile ─────────────────────────────────────────
#
#
#                                                  Dataset Overview
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ number of records               ┃ number of columns               ┃ percent complete records                    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 2                               │ 12                              │ 100.0%                                      │
# └─────────────────────────────────┴─────────────────────────────────┴─────────────────────────────────────────────┘
#
#
#                                               🌱 Seed-Dataset Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                          ┃               data type ┃                           number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ diagnosis                            │                  string │                                     2 (100.0%) │
# ├──────────────────────────────────────┼─────────────────────────┼────────────────────────────────────────────────┤
# │ patient_summary                      │                  string │                                     2 (100.0%) │
# └──────────────────────────────────────┴─────────────────────────┴────────────────────────────────────────────────┘
#
#
#                                                 🎲 Sampler Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                   ┃       data type ┃             number unique values ┃               sampler type ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ patient_sampler               │            dict │                       2 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ doctor_sampler                │            dict │                       2 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ patient_id                    │          string │                       2 (100.0%) │                       uuid │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ symptom_onset_date            │          string │                        1 (50.0%) │                   datetime │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ date_of_visit                 │          string │                        1 (50.0%) │                  timedelta │
# └───────────────────────────────┴─────────────────┴──────────────────────────────────┴────────────────────────────┘
#
#
#                                                 📝 LLM-Text Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                       ┃               ┃                            ┃     prompt tokens ┃      completion tokens ┃
# ┃ column name           ┃     data type ┃       number unique values ┃        per record ┃             per record ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ physician_notes       │        string │                 2 (100.0%) │     115.0 +/- 5.0 │       1398.0 +/- 885.3 │
# └───────────────────────┴───────────────┴────────────────────────────┴───────────────────┴────────────────────────┘
#
#
#                                                🧩 Expression Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                    ┃                 data type ┃                               number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ first_name                     │                    string │                                         2 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ last_name                      │                    string │                                         2 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ dob                            │                    string │                                         2 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ physician                      │                    string │                                         2 (100.0%) │
# └────────────────────────────────┴───────────────────────────┴────────────────────────────────────────────────────┘
#
#
# ╭────────────────────────────────────────────────── Table Notes ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  1. All token statistics are based on a sample of max(1000, len(dataset)) records.                              │
# │  2. Tokens are calculated using tiktoken's cl100k_base tokenizer.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### 🆙 Scale up!
#
# - Happy with your preview data?
#
# - Use the `create` method to submit larger Data Designer generation jobs.

# %%
results = data_designer.create(config_builder, num_records=10, dataset_name="tutorial-3")
# Out:
# [01:57:38] [INFO] 🎨 Creating Data Designer dataset
# [01:57:38] [INFO] ✅ Validation passed
# [01:57:38] [INFO] ⛓️ Sorting column configs into a Directed Acyclic Graph
# [01:57:38] [INFO] 🩺 Running health checks for models...
# [01:57:38] [INFO]   |-- 👀 Checking 'nvidia/nemotron-3-nano-30b-a3b' in provider named 'nvidia' for model alias 'nemotron-nano-v3'...
# [01:57:38] [INFO]   |-- ✅ Passed!
# [01:57:38] [INFO] ⏳ Processing batch 1 of 1
# [01:57:38] [INFO] 🌱 Sampling 10 records from seed dataset
# [01:57:38] [INFO]   |-- seed dataset size: 820 records
# [01:57:38] [INFO]   |-- sampling strategy: ordered
# [01:57:38] [INFO] 🎲 Preparing samplers to generate 10 records across 5 columns
# [01:57:38] [INFO] (💾 + 💾) Concatenating 2 datasets
# [01:57:38] [INFO] 🧩 Generating column `first_name` from expression
# [01:57:38] [INFO] 🧩 Generating column `last_name` from expression
# [01:57:38] [INFO] 🧩 Generating column `dob` from expression
# [01:57:38] [INFO] 🧩 Generating column `physician` from expression
# [01:57:38] [INFO] 📝 Preparing llm-text column generation
# [01:57:38] [INFO]   |-- column name: 'physician_notes'
# [01:57:38] [INFO]   |-- model config:
# {
#     "alias": "nemotron-nano-v3",
#     "model": "nvidia/nemotron-3-nano-30b-a3b",
#     "inference_parameters": {
#         "generation_type": "chat-completion",
#         "max_parallel_requests": 4,
#         "timeout": null,
#         "extra_body": {
#             "chat_template_kwargs": {
#                 "enable_thinking": false
#             }
#         },
#         "temperature": 1.0,
#         "top_p": 1.0,
#         "max_tokens": 2048
#     },
#     "provider": "nvidia"
# }
# [01:57:38] [INFO] 🐙 Processing llm-text column 'physician_notes' with 4 concurrent workers
# [01:57:49] [INFO] 📊 Model usage summary:
# {
#     "nvidia/nemotron-3-nano-30b-a3b": {
#         "token_usage": {
#             "input_tokens": 1432,
#             "output_tokens": 8724,
#             "total_tokens": 10156
#         },
#         "request_usage": {
#             "successful_requests": 10,
#             "failed_requests": 0,
#             "total_requests": 10
#         },
#         "tokens_per_second": 978,
#         "requests_per_minute": 57
#     }
# }
# [01:57:49] [INFO] 📐 Measuring dataset column statistics:
# [01:57:49] [INFO]   |-- 🌱 column: 'diagnosis'
# [01:57:49] [INFO]   |-- 🌱 column: 'patient_summary'
# [01:57:49] [INFO]   |-- 🎲 column: 'patient_sampler'
# [01:57:49] [INFO]   |-- 🎲 column: 'doctor_sampler'
# [01:57:49] [INFO]   |-- 🎲 column: 'patient_id'
# [01:57:49] [INFO]   |-- 🧩 column: 'first_name'
# [01:57:49] [INFO]   |-- 🧩 column: 'last_name'
# [01:57:49] [INFO]   |-- 🧩 column: 'dob'
# [01:57:49] [INFO]   |-- 🎲 column: 'symptom_onset_date'
# [01:57:49] [INFO]   |-- 🎲 column: 'date_of_visit'
# [01:57:49] [INFO]   |-- 🧩 column: 'physician'
# [01:57:49] [INFO]   |-- 📝 column: 'physician_notes'

# %%
# Load the generated dataset as a pandas DataFrame.
dataset = results.load_dataset()

dataset.head()
# Out:
#                  diagnosis                                    patient_summary  \
# 0     cervical spondylosis  I've been having a lot of pain in my neck and ...
# 1                 impetigo  I have a rash on my face that is getting worse...
# 2  urinary tract infection  I have been urinating blood. I sometimes feel ...
# 3                arthritis  I have been having trouble with my muscles and...
# 4                   dengue  I have been feeling really sick. My body hurts...
#
#                                      patient_sampler  \
# 0  {'age': 88, 'bachelors_field': 'education', 'b...
# 1  {'age': 27, 'bachelors_field': 'arts_humanitie...
# 2  {'age': 41, 'bachelors_field': 'no_degree', 'b...
# 3  {'age': 42, 'bachelors_field': 'no_degree', 'b...
# 4  {'age': 66, 'bachelors_field': 'no_degree', 'b...
#
#                                       doctor_sampler   patient_id  \
# 0  {'age': 57, 'bachelors_field': 'education', 'b...  PT-BC970B06
# 1  {'age': 71, 'bachelors_field': 'stem', 'birth_...  PT-A63E69D2
# 2  {'age': 99, 'bachelors_field': 'no_degree', 'b...  PT-E07A2165
# 3  {'age': 34, 'bachelors_field': 'no_degree', 'b...  PT-55CB903A
# 4  {'age': 55, 'bachelors_field': 'stem_related',...  PT-BF41B37F
#
#   symptom_onset_date date_of_visit first_name  last_name         dob  \
# 0         2024-05-14    2024-05-28       Dale   Reynolds  1937-06-02
# 1         2024-06-02    2024-06-12    Katrina   Thompson  1998-11-22
# 2         2024-03-30    2024-04-22       Sara      Booth  1984-09-11
# 3         2024-04-21    2024-04-28      Kiara       Tran  1983-11-17
# 4         2024-03-20    2024-04-06    Michael  Rodriguez  1959-09-10
#
#        physician                                    physician_notes
# 0   Dr. Garrison  **Visit Note - Dale Reynolds | 2024-05-28 | Dr...
# 1    Dr. Johnson  **Visit Note – 2024-06-12**
# **Patient:** Kat...
# 2     Dr. Rogers  **S.B. – 4/22/24 – 32F – UTI Follow-Up**
# - S...
# 3  Dr. Patterson  SOB: Stiffness, swelling, weakness, difficulty...
# 4   Dr. Gonzalez  Patient: Michael Rodriguez
# DOB: 06/15/1988  ...

# %%
# Load the analysis results into memory.
analysis = results.load_analysis()

analysis.to_report()
# Out:
# ──────────────────────────────────────── 🎨 Data Designer Dataset Profile ─────────────────────────────────────────
#
#
#                                                  Dataset Overview
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ number of records               ┃ number of columns               ┃ percent complete records                    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 10                              │ 12                              │ 100.0%                                      │
# └─────────────────────────────────┴─────────────────────────────────┴─────────────────────────────────────────────┘
#
#
#                                               🌱 Seed-Dataset Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                          ┃               data type ┃                           number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ diagnosis                            │                  string │                                      7 (70.0%) │
# ├──────────────────────────────────────┼─────────────────────────┼────────────────────────────────────────────────┤
# │ patient_summary                      │                  string │                                    10 (100.0%) │
# └──────────────────────────────────────┴─────────────────────────┴────────────────────────────────────────────────┘
#
#
#                                                 🎲 Sampler Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                   ┃       data type ┃             number unique values ┃               sampler type ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ patient_sampler               │            dict │                      10 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ doctor_sampler                │            dict │                      10 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ patient_id                    │          string │                      10 (100.0%) │                       uuid │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ symptom_onset_date            │          string │                      10 (100.0%) │                   datetime │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ date_of_visit                 │          string │                      10 (100.0%) │                  timedelta │
# └───────────────────────────────┴─────────────────┴──────────────────────────────────┴────────────────────────────┘
#
#
#                                                 📝 LLM-Text Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                       ┃               ┃                            ┃     prompt tokens ┃      completion tokens ┃
# ┃ column name           ┃     data type ┃       number unique values ┃        per record ┃             per record ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ physician_notes       │        string │                10 (100.0%) │     117.5 +/- 5.5 │        881.0 +/- 295.1 │
# └───────────────────────┴───────────────┴────────────────────────────┴───────────────────┴────────────────────────┘
#
#
#                                                🧩 Expression Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                    ┃                 data type ┃                               number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ first_name                     │                    string │                                        10 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ last_name                      │                    string │                                        10 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ dob                            │                    string │                                        10 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ physician                      │                    string │                                        10 (100.0%) │
# └────────────────────────────────┴───────────────────────────┴────────────────────────────────────────────────────┘
#
#
# ╭────────────────────────────────────────────────── Table Notes ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  1. All token statistics are based on a sample of max(1000, len(dataset)) records.                              │
# │  2. Tokens are calculated using tiktoken's cl100k_base tokenizer.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## ⏭️ Next Steps
#
# Check out the following notebook to learn more about:
#
# - [Providing images as context](https://nvidia-nemo.github.io/DataDesigner/latest/notebooks/4-providing-images-as-context/)
