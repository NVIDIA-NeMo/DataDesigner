# %% [markdown]
# # 🎨 Data Designer Tutorial: Structured Outputs and Jinja Expressions
#
# #### 📚 What you'll learn
#
# In this notebook, we will continue our exploration of Data Designer, demonstrating more advanced data generation using structured outputs and Jinja expressions.
#
# If this is your first time using Data Designer, we recommend starting with the [first notebook](https://nvidia-nemo.github.io/DataDesigner/latest/notebooks/1-the-basics/) in this tutorial series.

# %% [markdown]
# ### 📦 Import Data Designer
#
# - `data_designer.config` provides access to the configuration API.
#
# - `DataDesigner` is the main interface for data generation.

# %%
import data_designer.config as dd
from data_designer.interface import DataDesigner

# %% [markdown]
# ### ⚙️ Initialize the Data Designer interface
#
# - `DataDesigner` is the main object that is used to interface with the library.
#
# - When initialized without arguments, the [default model providers](https://nvidia-nemo.github.io/DataDesigner/latest/concepts/models/default-model-settings/) are used.

# %%
data_designer = DataDesigner()

# %% [markdown]
# ### 🎛️ Define model configurations
#
# - Each `ModelConfig` defines a model that can be used during the generation process.
#
# - The "model alias" is used to reference the model in the Data Designer config (as we will see below).
#
# - The "model provider" is the external service that hosts the model (see the [model config](https://nvidia-nemo.github.io/DataDesigner/latest/concepts/models/default-model-settings/) docs for more details).
#
# - By default, we use [build.nvidia.com](https://build.nvidia.com/models) as the model provider.

# %%
# This name is set in the model provider configuration.
MODEL_PROVIDER = "nvidia"

# The model ID is from build.nvidia.com.
MODEL_ID = "nvidia/nemotron-3-nano-30b-a3b"

# We choose this alias to be descriptive for our use case.
MODEL_ALIAS = "nemotron-nano-v3"

model_configs = [
    dd.ModelConfig(
        alias=MODEL_ALIAS,
        model=MODEL_ID,
        provider=MODEL_PROVIDER,
        inference_parameters=dd.ChatCompletionInferenceParams(
            temperature=1.0,
            top_p=1.0,
            max_tokens=2048,
            extra_body={"chat_template_kwargs": {"enable_thinking": False}},
        ),
    )
]

# %% [markdown]
# ### 🏗️ Initialize the Data Designer Config Builder
#
# - The Data Designer config defines the dataset schema and generation process.
#
# - The config builder provides an intuitive interface for building this configuration.
#
# - The list of model configs is provided to the builder at initialization.

# %%
config_builder = dd.DataDesignerConfigBuilder(model_configs=model_configs)

# %% [markdown]
# ### 🧑‍🎨 Designing our data
#
# - We will again create a product review dataset, but this time we will use structured outputs and Jinja expressions.
#
# - Structured outputs let you specify the exact schema of the data you want to generate.
#
# - Data Designer supports schemas specified using either json schema or Pydantic data models (recommended).
#
# <br>
#
# We'll define our structured outputs using [Pydantic](https://docs.pydantic.dev/latest/) data models
#
# > 💡 **Why Pydantic?**
# >
# > - Pydantic models provide better IDE support and type validation.
# >
# > - They are more Pythonic than raw JSON schemas.
# >
# > - They integrate seamlessly with Data Designer's structured output system.

# %%
from decimal import Decimal
from typing import Literal

from pydantic import BaseModel, Field


# We define a Product schema so that the name, description, and price are generated
# in one go, with the types and constraints specified.
class Product(BaseModel):
    name: str = Field(description="The name of the product")
    description: str = Field(description="A description of the product")
    price: Decimal = Field(description="The price of the product", ge=10, le=1000, decimal_places=2)


class ProductReview(BaseModel):
    rating: int = Field(description="The rating of the product", ge=1, le=5)
    customer_mood: Literal["irritated", "mad", "happy", "neutral", "excited"] = Field(
        description="The mood of the customer"
    )
    review: str = Field(description="A review of the product")

# %% [markdown]
# Next, let's design our product review dataset using a few more tricks compared to the previous notebook.

# %%
# Since we often only want a few attributes from Person objects, we can
# set drop=True in the column config to drop the column from the final dataset.
config_builder.add_column(
    dd.SamplerColumnConfig(
        name="customer",
        sampler_type=dd.SamplerType.PERSON_FROM_FAKER,
        params=dd.PersonFromFakerSamplerParams(),
        drop=True,
    )
)

config_builder.add_column(
    dd.SamplerColumnConfig(
        name="product_category",
        sampler_type=dd.SamplerType.CATEGORY,
        params=dd.CategorySamplerParams(
            values=[
                "Electronics",
                "Clothing",
                "Home & Kitchen",
                "Books",
                "Home Office",
            ],
        ),
    )
)

config_builder.add_column(
    dd.SamplerColumnConfig(
        name="product_subcategory",
        sampler_type=dd.SamplerType.SUBCATEGORY,
        params=dd.SubcategorySamplerParams(
            category="product_category",
            values={
                "Electronics": [
                    "Smartphones",
                    "Laptops",
                    "Headphones",
                    "Cameras",
                    "Accessories",
                ],
                "Clothing": [
                    "Men's Clothing",
                    "Women's Clothing",
                    "Winter Coats",
                    "Activewear",
                    "Accessories",
                ],
                "Home & Kitchen": [
                    "Appliances",
                    "Cookware",
                    "Furniture",
                    "Decor",
                    "Organization",
                ],
                "Books": [
                    "Fiction",
                    "Non-Fiction",
                    "Self-Help",
                    "Textbooks",
                    "Classics",
                ],
                "Home Office": [
                    "Desks",
                    "Chairs",
                    "Storage",
                    "Office Supplies",
                    "Lighting",
                ],
            },
        ),
    )
)

config_builder.add_column(
    dd.SamplerColumnConfig(
        name="target_age_range",
        sampler_type=dd.SamplerType.CATEGORY,
        params=dd.CategorySamplerParams(values=["18-25", "25-35", "35-50", "50-65", "65+"]),
    )
)

# Sampler columns support conditional params, which are used if the condition is met.
# In this example, we set the review style to rambling if the target age range is 18-25.
# Note conditional parameters are only supported for Sampler column types.
config_builder.add_column(
    dd.SamplerColumnConfig(
        name="review_style",
        sampler_type=dd.SamplerType.CATEGORY,
        params=dd.CategorySamplerParams(
            values=["rambling", "brief", "detailed", "structured with bullet points"],
            weights=[1, 2, 2, 1],
        ),
        conditional_params={
            "target_age_range == '18-25'": dd.CategorySamplerParams(values=["rambling"]),
        },
    )
)

# Optionally validate that the columns are configured correctly.
data_designer.validate(config_builder)
# Out:
# [12:13:56] [INFO] ✅ Validation passed

# %% [markdown]
# Next, we will use more advanced Jinja expressions to create new columns.
#
# Jinja expressions let you:
#
# - Access nested attributes: `{{ customer.first_name }}`
#
# - Combine values: `{{ customer.first_name }} {{ customer.last_name }}`
#
# - Use conditional logic: `{% if condition %}...{% endif %}`

# %%
# We can create new columns using Jinja expressions that reference
# existing columns, including attributes of nested objects.
config_builder.add_column(
    dd.ExpressionColumnConfig(name="customer_name", expr="{{ customer.first_name }} {{ customer.last_name }}")
)

config_builder.add_column(dd.ExpressionColumnConfig(name="customer_age", expr="{{ customer.age }}"))

config_builder.add_column(
    dd.LLMStructuredColumnConfig(
        name="product",
        prompt=(
            "Create a product in the '{{ product_category }}' category, focusing on products  "
            "related to '{{ product_subcategory }}'. The target age range of the ideal customer is "
            "{{ target_age_range }} years old. The product should be priced between $10 and $1000."
        ),
        output_format=Product,
        model_alias=MODEL_ALIAS,
    )
)

# We can even use if/else logic in our Jinja expressions to create more complex prompt patterns.
config_builder.add_column(
    dd.LLMStructuredColumnConfig(
        name="customer_review",
        prompt=(
            "Your task is to write a review for the following product:\n\n"
            "Product Name: {{ product.name }}\n"
            "Product Description: {{ product.description }}\n"
            "Price: {{ product.price }}\n\n"
            "Imagine your name is {{ customer_name }} and you are from {{ customer.city }}, {{ customer.state }}. "
            "Write the review in a style that is '{{ review_style }}'."
            "{% if target_age_range == '18-25' %}"
            "Make sure the review is more informal and conversational.\n"
            "{% else %}"
            "Make sure the review is more formal and structured.\n"
            "{% endif %}"
            "The review field should contain only the review, no other text."
        ),
        output_format=ProductReview,
        model_alias=MODEL_ALIAS,
    )
)

data_designer.validate(config_builder)
# Out:
# [12:13:56] [INFO] ✅ Validation passed

# %% [markdown]
# ### 🔁 Iteration is key – preview the dataset!
#
# 1. Use the `preview` method to generate a sample of records quickly.
#
# 2. Inspect the results for quality and format issues.
#
# 3. Adjust column configurations, prompts, or parameters as needed.
#
# 4. Re-run the preview until satisfied.

# %%
preview = data_designer.preview(config_builder, num_records=2)
# Out:
# [12:13:56] [INFO] 🎥 Preview generation in progress
# [12:13:56] [INFO] ✅ Validation passed
# [12:13:56] [INFO] ⛓️ Sorting column configs into a Directed Acyclic Graph
# [12:13:56] [INFO] 🩺 Running health checks for models...
# [12:13:56] [INFO]   |-- 👀 Checking 'nvidia/nemotron-3-nano-30b-a3b' in provider named 'nvidia' for model alias 'nemotron-nano-v3'...
# [12:13:57] [INFO]   |-- ✅ Passed!
# [12:13:57] [INFO] 🎲 Preparing samplers to generate 2 records across 5 columns
# [12:13:57] [INFO] 🧩 Generating column `customer_name` from expression
# [12:13:57] [INFO] 🧩 Generating column `customer_age` from expression
# [12:13:57] [INFO] 🗂️ llm-structured model config for column 'product'
# [12:13:57] [INFO]   |-- model: 'nvidia/nemotron-3-nano-30b-a3b'
# [12:13:57] [INFO]   |-- model alias: 'nemotron-nano-v3'
# [12:13:57] [INFO]   |-- model provider: 'nvidia'
# [12:13:57] [INFO]   |-- inference parameters:
# [12:13:57] [INFO]   |  |-- generation_type=chat-completion
# [12:13:57] [INFO]   |  |-- max_parallel_requests=4
# [12:13:57] [INFO]   |  |-- extra_body={'chat_template_kwargs': {'enable_thinking': False}}
# [12:13:57] [INFO]   |  |-- temperature=1.00
# [12:13:57] [INFO]   |  |-- top_p=1.00
# [12:13:57] [INFO]   |  |-- max_tokens=2048
# [12:13:57] [INFO] ⚡️ Processing llm-structured column 'product' with 4 concurrent workers
# [12:13:57] [INFO] ⏱️ llm-structured column 'product' will report progress after each record
# [12:13:58] [INFO]   |-- 🌗 llm-structured column 'product' progress: 1/2 (50%) complete, 1 ok, 0 failed, 1.27 rec/s, eta 0.8s
# [12:13:58] [INFO]   |-- 🌕 llm-structured column 'product' progress: 2/2 (100%) complete, 2 ok, 0 failed, 2.12 rec/s, eta 0.0s
# [12:13:58] [INFO] 🗂️ llm-structured model config for column 'customer_review'
# [12:13:58] [INFO]   |-- model: 'nvidia/nemotron-3-nano-30b-a3b'
# [12:13:58] [INFO]   |-- model alias: 'nemotron-nano-v3'
# [12:13:58] [INFO]   |-- model provider: 'nvidia'
# [12:13:58] [INFO]   |-- inference parameters:
# [12:13:58] [INFO]   |  |-- generation_type=chat-completion
# [12:13:58] [INFO]   |  |-- max_parallel_requests=4
# [12:13:58] [INFO]   |  |-- extra_body={'chat_template_kwargs': {'enable_thinking': False}}
# [12:13:58] [INFO]   |  |-- temperature=1.00
# [12:13:58] [INFO]   |  |-- top_p=1.00
# [12:13:58] [INFO]   |  |-- max_tokens=2048
# [12:13:58] [INFO] ⚡️ Processing llm-structured column 'customer_review' with 4 concurrent workers
# [12:13:58] [INFO] ⏱️ llm-structured column 'customer_review' will report progress after each record
# [12:13:59] [INFO]   |-- 🐥 llm-structured column 'customer_review' progress: 1/2 (50%) complete, 1 ok, 0 failed, 1.00 rec/s, eta 1.0s
# [12:14:00] [INFO]   |-- 🐔 llm-structured column 'customer_review' progress: 2/2 (100%) complete, 2 ok, 0 failed, 1.01 rec/s, eta 0.0s
# [12:14:00] [INFO] 📊 Model usage summary:
# [12:14:00] [INFO]   |-- model: nvidia/nemotron-3-nano-30b-a3b
# [12:14:00] [INFO]   |-- tokens: input=1427, output=824, total=2251, tps=697
# [12:14:00] [INFO]   |-- requests: success=4, failed=0, total=4, rpm=74
# [12:14:00] [INFO] 🙈 Dropping columns: ['customer']
# [12:14:00] [INFO] 📐 Measuring dataset column statistics:
# [12:14:00] [INFO]   |-- 🎲 column: 'product_category'
# [12:14:00] [INFO]   |-- 🎲 column: 'product_subcategory'
# [12:14:00] [INFO]   |-- 🎲 column: 'target_age_range'
# [12:14:00] [INFO]   |-- 🎲 column: 'review_style'
# [12:14:00] [INFO]   |-- 🧩 column: 'customer_name'
# [12:14:00] [INFO]   |-- 🧩 column: 'customer_age'
# [12:14:00] [INFO]   |-- 🗂️ column: 'product'
# [12:14:00] [INFO]   |-- 🗂️ column: 'customer_review'
# [12:14:00] [INFO] 👏 Preview complete!

# %%
# Run this cell multiple times to cycle through the 2 preview records.
preview.display_sample_record()
# Out:
# <div style='text-align:center;font-family:Menlo,Monaco,Consolas,monospace;font-size:12px;color:#666;margin:8px 0;'>[index: 0]</div>
#
#                                               Generated Columns
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name                ┃ Value                                                                                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ product_category    │ Electronics                                                                          │
# ├─────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┤
# │ product_subcategory │ Smartphones                                                                          │
# ├─────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┤
# │ target_age_range    │ 50-65                                                                                │
# ├─────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┤
# │ review_style        │ rambling                                                                             │
# ├─────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┤
# │ product             │ {                                                                                    │
# │                     │     'name': 'Zenith One+ Smartphone',                                                │
# │                     │     'description': 'The Zenith One+ is a senior-friendly smartphone designed for     │
# │                     │ users aged 50-65. It features a large 6.5-inch HD+ display with high contrast text   │
# │                     │ and adjustable font scaling for comfortable reading. The device runs on a            │
# │                     │ simplified, intuitive interface with one-touch accessibility features like voice     │
# │                     │ command activation, emergency SOS button, and a dedicated medical alert system.      │
# │                     │ Powered by a 5000mAh battery for up to 3 days of use, it includes a triple-camera    │
# │                     │ system optimized for low-light photography with large 48MP sensors and AI-enhanced   │
# │                     │ scene recognition. The phone also offers a built-in digital wallet for secure        │
# │                     │ payments and a durable, anti-fingerprint matte finish body that resists fingerprints │
# │                     │ and scratches. All settings are customizable for better visibility, including a      │
# │                     │ heat-to-eye mode that reduces blue light for eye comfort during extended use.',      │
# │                     │     'price': 329.99                                                                  │
# │                     │ }                                                                                    │
# ├─────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┤
# │ customer_review     │ {                                                                                    │
# │                     │     'rating': 5,                                                                     │
# │                     │     'customer_mood': 'happy',                                                        │
# │                     │     'review': 'I purchased the Zenith One+ Smartphone for my mother in Brucetown,    │
# │                     │ Oregon after thoroughly researching options for seniors, and I can honestly say it   │
# │                     │ has transformed her daily routine; the large 6.5-inch HD+ display with adjustable    │
# │                     │ font scaling makes reading recipes and news effortless, while the simplified         │
# │                     │ interface with one-touch accessibility features like the emergency SOS button and a  │
# │                     │ dedicated medical alert system has given both of us tremendous peace of mind,        │
# │                     │ especially considering her occasional fragility and the need for immediate           │
# │                     │ assistance; the stellar 5000mAh battery lasting up to three days means I rarely have │
# │                     │ to worry about charging, and the triple-camera system with its large 48MP sensors    │
# │                     │ and AI-enhanced scene recognition consistently produces sharp, clear photos even in  │
# │                     │ low-light conditions, capturing family gatherings beautifully—the matte,             │
# │                     │ anti-fingerprint finish also keeps the device looking pristine despite frequent      │
# │                     │ handling; moreover, the built-in digital wallet streamlines her grocery purchases,   │
# │                     │ and the heat-to-eye mode, which reduces blue light for eye comfort during extended   │
# │                     │ viewing sessions, demonstrates thoughtful attention to visual health; overall, this  │
# │                     │ device perfectly merges functionality with user-centric design, and for seniors      │
# │                     │ seeking a reliable, easy-to-use, and reassuring mobile experience, the Zenith One+   │
# │                     │ truly earns its price point of $329.99, leaving me genuinely excited about           │
# │                     │ recommending it to friends and family seeking similar solutions.'                    │
# │                     │ }                                                                                    │
# ├─────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┤
# │ customer_name       │ Karen Barrera                                                                        │
# ├─────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┤
# │ customer_age        │ 89                                                                                   │
# └─────────────────────┴──────────────────────────────────────────────────────────────────────────────────────┘

# %%
# The preview dataset is available as a pandas DataFrame.
preview.dataset
# Out:
#   product_category product_subcategory target_age_range review_style  \
# 0      Electronics         Smartphones            50-65     rambling
# 1      Home Office               Desks            25-35     detailed
#
#    customer_name customer_age  \
# 0  Karen Barrera           89
# 1  Lucas Allison           97
#
#                                              product  \
# 0  {'name': 'Zenith One+ Smartphone', 'descriptio...
# 1  {'name': 'Ergonomic Adjustable Height Desk', '...
#
#                                      customer_review
# 0  {'rating': 5, 'customer_mood': 'happy', 'revie...
# 1  {'rating': 5, 'customer_mood': 'happy', 'revie...

# %% [markdown]
# ### 📊 Analyze the generated data
#
# - Data Designer automatically generates a basic statistical analysis of the generated data.
#
# - This analysis is available via the `analysis` property of generation result objects.

# %%
# Print the analysis as a table.
preview.analysis.to_report()
# Out:
# ──────────────────────────────────────── 🎨 Data Designer Dataset Profile ─────────────────────────────────────────
#
#
#                                                  Dataset Overview
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ number of records               ┃ number of columns               ┃ percent complete records                    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 2                               │ 8                               │ 100.0%                                      │
# └─────────────────────────────────┴─────────────────────────────────┴─────────────────────────────────────────────┘
#
#
#                                                 🎲 Sampler Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                      ┃        data type ┃               number unique values ┃         sampler type ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩
# │ product_category                 │           string │                         2 (100.0%) │             category │
# ├──────────────────────────────────┼──────────────────┼────────────────────────────────────┼──────────────────────┤
# │ product_subcategory              │           string │                         2 (100.0%) │          subcategory │
# ├──────────────────────────────────┼──────────────────┼────────────────────────────────────┼──────────────────────┤
# │ target_age_range                 │           string │                         2 (100.0%) │             category │
# ├──────────────────────────────────┼──────────────────┼────────────────────────────────────┼──────────────────────┤
# │ review_style                     │           string │                         2 (100.0%) │             category │
# └──────────────────────────────────┴──────────────────┴────────────────────────────────────┴──────────────────────┘
#
#
#                                              🗂️ LLM-Structured Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                      ┃               ┃                            ┃       prompt tokens ┃     completion tokens ┃
# ┃ column name          ┃     data type ┃       number unique values ┃          per record ┃            per record ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ product              │          dict │                 2 (100.0%) │       265.0 +/- 0.0 │        134.5 +/- 78.5 │
# ├──────────────────────┼───────────────┼────────────────────────────┼─────────────────────┼───────────────────────┤
# │ customer_review      │          dict │                 2 (100.0%) │      389.5 +/- 57.5 │        227.0 +/- 89.1 │
# └──────────────────────┴───────────────┴────────────────────────────┴─────────────────────┴───────────────────────┘
#
#
#                                                🧩 Expression Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                       ┃                data type ┃                             number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ customer_name                     │                   string │                                       2 (100.0%) │
# ├───────────────────────────────────┼──────────────────────────┼──────────────────────────────────────────────────┤
# │ customer_age                      │                   string │                                       2 (100.0%) │
# └───────────────────────────────────┴──────────────────────────┴──────────────────────────────────────────────────┘
#
#
# ╭────────────────────────────────────────────────── Table Notes ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  1. All token statistics are based on a sample of max(1000, len(dataset)) records.                              │
# │  2. Tokens are calculated using tiktoken's cl100k_base tokenizer.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### 🆙 Scale up!
#
# - Happy with your preview data?
#
# - Use the `create` method to submit larger Data Designer generation jobs.

# %%
results = data_designer.create(config_builder, num_records=10, dataset_name="tutorial-2")
# Out:
# [12:14:00] [INFO] 🎨 Creating Data Designer dataset
# [12:14:00] [INFO] ✅ Validation passed
# [12:14:00] [INFO] ⛓️ Sorting column configs into a Directed Acyclic Graph
# [12:14:00] [INFO] 🩺 Running health checks for models...
# [12:14:00] [INFO]   |-- 👀 Checking 'nvidia/nemotron-3-nano-30b-a3b' in provider named 'nvidia' for model alias 'nemotron-nano-v3'...
# [12:14:01] [INFO]   |-- ✅ Passed!
# [12:14:01] [INFO] ⏳ Processing batch 1 of 1
# [12:14:01] [INFO] 🎲 Preparing samplers to generate 10 records across 5 columns
# [12:14:01] [INFO] 🧩 Generating column `customer_name` from expression
# [12:14:01] [INFO] 🧩 Generating column `customer_age` from expression
# [12:14:01] [INFO] 🗂️ llm-structured model config for column 'product'
# [12:14:01] [INFO]   |-- model: 'nvidia/nemotron-3-nano-30b-a3b'
# [12:14:01] [INFO]   |-- model alias: 'nemotron-nano-v3'
# [12:14:01] [INFO]   |-- model provider: 'nvidia'
# [12:14:01] [INFO]   |-- inference parameters:
# [12:14:01] [INFO]   |  |-- generation_type=chat-completion
# [12:14:01] [INFO]   |  |-- max_parallel_requests=4
# [12:14:01] [INFO]   |  |-- extra_body={'chat_template_kwargs': {'enable_thinking': False}}
# [12:14:01] [INFO]   |  |-- temperature=1.00
# [12:14:01] [INFO]   |  |-- top_p=1.00
# [12:14:01] [INFO]   |  |-- max_tokens=2048
# [12:14:01] [INFO] ⚡️ Processing llm-structured column 'product' with 4 concurrent workers
# [12:14:01] [INFO] ⏱️ llm-structured column 'product' will report progress after each record
# [12:14:01] [INFO]   |-- 🚶 llm-structured column 'product' progress: 1/10 (10%) complete, 1 ok, 0 failed, 1.53 rec/s, eta 5.9s
# [12:14:01] [INFO]   |-- 🚶 llm-structured column 'product' progress: 2/10 (20%) complete, 2 ok, 0 failed, 2.66 rec/s, eta 3.0s
# [12:14:01] [INFO]   |-- 🐴 llm-structured column 'product' progress: 3/10 (30%) complete, 3 ok, 0 failed, 3.97 rec/s, eta 1.8s
# [12:14:02] [INFO]   |-- 🐴 llm-structured column 'product' progress: 4/10 (40%) complete, 4 ok, 0 failed, 3.65 rec/s, eta 1.6s
# [12:14:02] [INFO]   |-- 🚗 llm-structured column 'product' progress: 5/10 (50%) complete, 5 ok, 0 failed, 3.78 rec/s, eta 1.3s
# [12:14:02] [INFO]   |-- 🚗 llm-structured column 'product' progress: 6/10 (60%) complete, 6 ok, 0 failed, 4.22 rec/s, eta 0.9s
# [12:14:02] [INFO]   |-- 🚗 llm-structured column 'product' progress: 7/10 (70%) complete, 7 ok, 0 failed, 4.67 rec/s, eta 0.6s
# [12:14:03] [INFO]   |-- ✈️ llm-structured column 'product' progress: 8/10 (80%) complete, 8 ok, 0 failed, 3.55 rec/s, eta 0.6s
# [12:14:03] [INFO]   |-- ✈️ llm-structured column 'product' progress: 9/10 (90%) complete, 9 ok, 0 failed, 3.57 rec/s, eta 0.3s
# [12:14:04] [INFO]   |-- 🚀 llm-structured column 'product' progress: 10/10 (100%) complete, 10 ok, 0 failed, 3.53 rec/s, eta 0.0s
# [12:14:04] [INFO] 🗂️ llm-structured model config for column 'customer_review'
# [12:14:04] [INFO]   |-- model: 'nvidia/nemotron-3-nano-30b-a3b'
# [12:14:04] [INFO]   |-- model alias: 'nemotron-nano-v3'
# [12:14:04] [INFO]   |-- model provider: 'nvidia'
# [12:14:04] [INFO]   |-- inference parameters:
# [12:14:04] [INFO]   |  |-- generation_type=chat-completion
# [12:14:04] [INFO]   |  |-- max_parallel_requests=4
# [12:14:04] [INFO]   |  |-- extra_body={'chat_template_kwargs': {'enable_thinking': False}}
# [12:14:04] [INFO]   |  |-- temperature=1.00
# [12:14:04] [INFO]   |  |-- top_p=1.00
# [12:14:04] [INFO]   |  |-- max_tokens=2048
# [12:14:04] [INFO] ⚡️ Processing llm-structured column 'customer_review' with 4 concurrent workers
# [12:14:04] [INFO] ⏱️ llm-structured column 'customer_review' will report progress after each record
# [12:14:04] [INFO]   |-- 🌑 llm-structured column 'customer_review' progress: 1/10 (10%) complete, 1 ok, 0 failed, 1.20 rec/s, eta 7.5s
# [12:14:05] [INFO]   |-- 🌑 llm-structured column 'customer_review' progress: 2/10 (20%) complete, 2 ok, 0 failed, 1.86 rec/s, eta 4.3s
# [12:14:05] [INFO]   |-- 🌘 llm-structured column 'customer_review' progress: 3/10 (30%) complete, 3 ok, 0 failed, 2.42 rec/s, eta 2.9s
# [12:14:06] [INFO]   |-- 🌘 llm-structured column 'customer_review' progress: 4/10 (40%) complete, 4 ok, 0 failed, 1.56 rec/s, eta 3.8s
# [12:14:06] [INFO]   |-- 🌗 llm-structured column 'customer_review' progress: 5/10 (50%) complete, 5 ok, 0 failed, 1.79 rec/s, eta 2.8s
# [12:14:07] [INFO]   |-- 🌗 llm-structured column 'customer_review' progress: 6/10 (60%) complete, 6 ok, 0 failed, 1.93 rec/s, eta 2.1s
# [12:14:07] [INFO]   |-- 🌗 llm-structured column 'customer_review' progress: 7/10 (70%) complete, 7 ok, 0 failed, 2.11 rec/s, eta 1.4s
# [12:14:07] [INFO]   |-- 🌖 llm-structured column 'customer_review' progress: 8/10 (80%) complete, 8 ok, 0 failed, 2.18 rec/s, eta 0.9s
# [12:14:09] [INFO]   |-- 🌖 llm-structured column 'customer_review' progress: 9/10 (90%) complete, 9 ok, 0 failed, 1.64 rec/s, eta 0.6s
# [12:14:11] [INFO]   |-- 🌕 llm-structured column 'customer_review' progress: 10/10 (100%) complete, 10 ok, 0 failed, 1.30 rec/s, eta 0.0s
# [12:14:11] [INFO] 🙈 Dropping columns: ['customer']
# [12:14:11] [INFO] 📊 Model usage summary:
# [12:14:11] [INFO]   |-- model: nvidia/nemotron-3-nano-30b-a3b
# [12:14:11] [INFO]   |-- tokens: input=6494, output=3614, total=10108, tps=933
# [12:14:11] [INFO]   |-- requests: success=20, failed=0, total=20, rpm=110
# [12:14:11] [INFO] 📐 Measuring dataset column statistics:
# [12:14:11] [INFO]   |-- 🎲 column: 'product_category'
# [12:14:11] [INFO]   |-- 🎲 column: 'product_subcategory'
# [12:14:11] [INFO]   |-- 🎲 column: 'target_age_range'
# [12:14:11] [INFO]   |-- 🎲 column: 'review_style'
# [12:14:11] [INFO]   |-- 🧩 column: 'customer_name'
# [12:14:11] [INFO]   |-- 🧩 column: 'customer_age'
# [12:14:11] [INFO]   |-- 🗂️ column: 'product'
# [12:14:12] [INFO]   |-- 🗂️ column: 'customer_review'

# %%
# Load the generated dataset as a pandas DataFrame.
dataset = results.load_dataset()

dataset.head()
# Out:
#   product_category product_subcategory target_age_range  \
# 0   Home & Kitchen        Organization            25-35
# 1         Clothing    Women's Clothing            50-65
# 2   Home & Kitchen            Cookware            25-35
# 3            Books           Textbooks            35-50
# 4            Books             Fiction            25-35
#
#                     review_style  customer_name customer_age  \
# 0                       rambling     Isaac Koch           55
# 1  structured with bullet points   Chloe Fisher           92
# 2  structured with bullet points  William Evans           72
# 3                       detailed     Paul Green           33
# 4                       detailed    Susan Moses           76
#
#                                              product  \
# 0  {'description': 'A set of stackable, modular d...
# 1  {'description': 'Luxurious 100% cashmere wrap ...
# 2  {'description': 'A 3‑piece non‑stick skillet s...
# 3  {'description': 'A concise, step-by-step handb...
# 4  {'description': "A deluxe, limited-edition har...
#
#                                      customer_review
# 0  {'customer_mood': 'happy', 'rating': 5, 'revie...
# 1  {'customer_mood': 'happy', 'rating': 5, 'revie...
# 2  {'customer_mood': 'happy', 'rating': 4, 'revie...
# 3  {'customer_mood': 'happy', 'rating': 5, 'revie...
# 4  {'customer_mood': 'happy', 'rating': 5, 'revie...

# %%
# Load the analysis results into memory.
analysis = results.load_analysis()

analysis.to_report()
# Out:
# ──────────────────────────────────────── 🎨 Data Designer Dataset Profile ─────────────────────────────────────────
#
#
#                                                  Dataset Overview
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ number of records               ┃ number of columns               ┃ percent complete records                    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 10                              │ 8                               │ 100.0%                                      │
# └─────────────────────────────────┴─────────────────────────────────┴─────────────────────────────────────────────┘
#
#
#                                                 🎲 Sampler Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                      ┃        data type ┃               number unique values ┃         sampler type ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩
# │ product_category                 │           string │                          4 (40.0%) │             category │
# ├──────────────────────────────────┼──────────────────┼────────────────────────────────────┼──────────────────────┤
# │ product_subcategory              │           string │                          8 (80.0%) │          subcategory │
# ├──────────────────────────────────┼──────────────────┼────────────────────────────────────┼──────────────────────┤
# │ target_age_range                 │           string │                          5 (50.0%) │             category │
# ├──────────────────────────────────┼──────────────────┼────────────────────────────────────┼──────────────────────┤
# │ review_style                     │           string │                          3 (30.0%) │             category │
# └──────────────────────────────────┴──────────────────┴────────────────────────────────────┴──────────────────────┘
#
#
#                                              🗂️ LLM-Structured Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                      ┃               ┃                            ┃       prompt tokens ┃     completion tokens ┃
# ┃ column name          ┃     data type ┃       number unique values ┃          per record ┃            per record ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ product              │          dict │                10 (100.0%) │       264.5 +/- 0.9 │         75.0 +/- 16.2 │
# ├──────────────────────┼───────────────┼────────────────────────────┼─────────────────────┼───────────────────────┤
# │ customer_review      │          dict │                10 (100.0%) │      332.0 +/- 14.6 │       217.5 +/- 127.2 │
# └──────────────────────┴───────────────┴────────────────────────────┴─────────────────────┴───────────────────────┘
#
#
#                                                🧩 Expression Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                       ┃                data type ┃                             number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ customer_name                     │                   string │                                      10 (100.0%) │
# ├───────────────────────────────────┼──────────────────────────┼──────────────────────────────────────────────────┤
# │ customer_age                      │                   string │                                        9 (90.0%) │
# └───────────────────────────────────┴──────────────────────────┴──────────────────────────────────────────────────┘
#
#
# ╭────────────────────────────────────────────────── Table Notes ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  1. All token statistics are based on a sample of max(1000, len(dataset)) records.                              │
# │  2. Tokens are calculated using tiktoken's cl100k_base tokenizer.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## ⏭️ Next Steps
#
# Check out the following notebook to learn more about:
#
# - [Seeding synthetic data generation with an external dataset](https://nvidia-nemo.github.io/DataDesigner/latest/notebooks/3-seeding-with-a-dataset/)
#
# - [Providing images as context](https://nvidia-nemo.github.io/DataDesigner/latest/notebooks/4-providing-images-as-context/)
#
# - [Generating images](https://nvidia-nemo.github.io/DataDesigner/latest/notebooks/5-generating-images/)
