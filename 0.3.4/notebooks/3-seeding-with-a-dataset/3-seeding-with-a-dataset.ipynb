# %% [markdown]
# # 🎨 Data Designer Tutorial: Seeding Synthetic Data Generation with an External Dataset
#
# #### 📚 What you'll learn
#
# In this notebook, we will demonstrate how to seed synthetic data generation in Data Designer with an external dataset.
#
# If this is your first time using Data Designer, we recommend starting with the [first notebook](https://nvidia-nemo.github.io/DataDesigner/latest/notebooks/1-the-basics/) in this tutorial series.

# %% [markdown]
# ### 📦 Import the essentials
#
# - The `essentials` module provides quick access to the most commonly used objects.

# %%
from data_designer.essentials import (
    ChatCompletionInferenceParams,
    DataDesigner,
    DataDesignerConfigBuilder,
    LocalFileSeedSource,
    ModelConfig,
)

# %% [markdown]
# ### ⚙️ Initialize the Data Designer interface
#
# - `DataDesigner` is the main object is responsible for managing the data generation process.
#
# - When initialized without arguments, the [default model providers](https://nvidia-nemo.github.io/DataDesigner/latest/concepts/models/default-model-settings/) are used.

# %%
data_designer = DataDesigner()

# %% [markdown]
# ### 🎛️ Define model configurations
#
# - Each `ModelConfig` defines a model that can be used during the generation process.
#
# - The "model alias" is used to reference the model in the Data Designer config (as we will see below).
#
# - The "model provider" is the external service that hosts the model (see the [model config](https://nvidia-nemo.github.io/DataDesigner/latest/concepts/models/default-model-settings/) docs for more details).
#
# - By default, we use [build.nvidia.com](https://build.nvidia.com/models) as the model provider.

# %%
# This name is set in the model provider configuration.
MODEL_PROVIDER = "nvidia"

# The model ID is from build.nvidia.com.
MODEL_ID = "nvidia/nemotron-3-nano-30b-a3b"

# We choose this alias to be descriptive for our use case.
MODEL_ALIAS = "nemotron-nano-v3"

model_configs = [
    ModelConfig(
        alias=MODEL_ALIAS,
        model=MODEL_ID,
        provider=MODEL_PROVIDER,
        inference_parameters=ChatCompletionInferenceParams(
            temperature=1.0,
            top_p=1.0,
            max_tokens=2048,
            extra_body={"chat_template_kwargs": {"enable_thinking": False}},
        ),
    )
]

# %% [markdown]
# ### 🏗️ Initialize the Data Designer Config Builder
#
# - The Data Designer config defines the dataset schema and generation process.
#
# - The config builder provides an intuitive interface for building this configuration.
#
# - The list of model configs is provided to the builder at initialization.

# %%
config_builder = DataDesignerConfigBuilder(model_configs=model_configs)

# %% [markdown]
# ## 🏥 Prepare a seed dataset
#
# - For this notebook, we'll create a synthetic dataset of patient notes.
#
# - We will _seed_ the generation process with a [symptom-to-diagnosis dataset](https://huggingface.co/datasets/gretelai/symptom_to_diagnosis).
#
# - We already have the dataset downloaded in the [data](../data) directory of this repository.
#
# <br>
#
# > 🌱 **Why use a seed dataset?**
# >
# > - Seed datasets let you steer the generation process by providing context that is specific to your use case.
# >
# > - Seed datasets are also an excellent way to inject real-world diversity into your synthetic data.
# >
# > - During generation, prompt templates can reference any of the seed dataset fields.

# %%
# Download sample dataset from Github
import urllib.request

url = "https://raw.githubusercontent.com/NVIDIA/GenerativeAIExamples/refs/heads/main/nemo/NeMo-Data-Designer/data/gretelai_symptom_to_diagnosis.csv"
local_filename, _ = urllib.request.urlretrieve(url, "gretelai_symptom_to_diagnosis.csv")

# Seed datasets are passed as reference objects to the config builder.
seed_source = LocalFileSeedSource(path=local_filename)

config_builder.with_seed_dataset(seed_source)
# Out:
# DataDesignerConfigBuilder()

# %% [markdown]
# ## 🎨 Designing our synthetic patient notes dataset
#
# - Here we use `add_column` with keyword arguments (rather than imported config objects).
#
# - Generally, we recommend using concrete objects, but this is a convenient shorthand.
#
# - **Note**: The prompt template can reference fields from our seed dataset:
#   - `{{ diagnosis }}` - the medical diagnosis from the seed data
#   - `{{ patient_summary }}` - the symptom description from the seed data

# %%
config_builder.add_column(
    name="patient_sampler",
    column_type="sampler",
    sampler_type="person_from_faker",
)

config_builder.add_column(
    name="doctor_sampler",
    column_type="sampler",
    sampler_type="person_from_faker",
)

config_builder.add_column(
    name="patient_id",
    column_type="sampler",
    sampler_type="uuid",
    params={
        "prefix": "PT-",
        "short_form": True,
        "uppercase": True,
    },
)

config_builder.add_column(
    name="first_name",
    column_type="expression",
    expr="{{ patient_sampler.first_name}}",
)

config_builder.add_column(
    name="last_name",
    column_type="expression",
    expr="{{ patient_sampler.last_name }}",
)


config_builder.add_column(
    name="dob",
    column_type="expression",
    expr="{{ patient_sampler.birth_date }}",
)

config_builder.add_column(
    name="symptom_onset_date",
    column_type="sampler",
    sampler_type="datetime",
    params={"start": "2024-01-01", "end": "2024-12-31"},
)

config_builder.add_column(
    name="date_of_visit",
    column_type="sampler",
    sampler_type="timedelta",
    params={"dt_min": 1, "dt_max": 30, "reference_column_name": "symptom_onset_date"},
)

config_builder.add_column(
    name="physician",
    column_type="expression",
    expr="Dr. {{ doctor_sampler.last_name }}",
)

config_builder.add_column(
    name="physician_notes",
    column_type="llm-text",
    prompt="""\
You are a primary-care physician who just had an appointment with {{ first_name }} {{ last_name }},
who has been struggling with symptoms from {{ diagnosis }} since {{ symptom_onset_date }}.
The date of today's visit is {{ date_of_visit }}.

{{ patient_summary }}

Write careful notes about your visit with {{ first_name }},
as Dr. {{ doctor_sampler.first_name }} {{ doctor_sampler.last_name }}.

Format the notes as a busy doctor might.
Respond with only the notes, no other text.
""",
    model_alias=MODEL_ALIAS,
)

data_designer.validate(config_builder)
# Out:
# [22:38:55] [INFO] ✅ Validation passed

# %% [markdown]
# ### 🔁 Iteration is key – preview the dataset!
#
# 1. Use the `preview` method to generate a sample of records quickly.
#
# 2. Inspect the results for quality and format issues.
#
# 3. Adjust column configurations, prompts, or parameters as needed.
#
# 4. Re-run the preview until satisfied.

# %%
preview = data_designer.preview(config_builder, num_records=2)
# Out:
# [22:38:55] [INFO] 📺 Preview generation in progress
# [22:38:55] [INFO] ✅ Validation passed
# [22:38:55] [INFO] ⛓️ Sorting column configs into a Directed Acyclic Graph
# [22:38:55] [INFO] 🩺 Running health checks for models...
# [22:38:55] [INFO]   |-- 👀 Checking 'nvidia/nemotron-3-nano-30b-a3b' in provider named 'nvidia' for model alias 'nemotron-nano-v3'...
# [22:38:56] [INFO]   |-- ✅ Passed!
# [22:38:56] [INFO] 🌱 Sampling 2 records from seed dataset
# [22:38:56] [INFO]   |-- seed dataset size: 820 records
# [22:38:56] [INFO]   |-- sampling strategy: ordered
# [22:38:56] [INFO] 🎲 Preparing samplers to generate 2 records across 5 columns
# [22:38:56] [INFO] (💾 + 💾) Concatenating 2 datasets
# [22:38:56] [INFO] 🧩 Generating column `first_name` from expression
# [22:38:56] [INFO] 🧩 Generating column `last_name` from expression
# [22:38:56] [INFO] 🧩 Generating column `dob` from expression
# [22:38:56] [INFO] 🧩 Generating column `physician` from expression
# [22:38:56] [INFO] llm-text model configuration for generating column 'physician_notes'
# [22:38:56] [INFO]   |-- model: 'nvidia/nemotron-3-nano-30b-a3b'
# [22:38:56] [INFO]   |-- model alias: 'nemotron-nano-v3'
# [22:38:56] [INFO]   |-- model provider: 'nvidia'
# [22:38:56] [INFO]   |-- inference parameters: generation_type=chat-completion, max_parallel_requests=4, extra_body={'chat_template_kwargs': {'enable_thinking': False}}, temperature=1.00, top_p=1.00, max_tokens=2048
# [22:38:56] [INFO] 🐙 Processing llm-text column 'physician_notes' with 4 concurrent workers
# [22:39:02] [INFO] 📊 Model usage summary:
# {
#     "nvidia/nemotron-3-nano-30b-a3b": {
#         "token_usage": {
#             "input_tokens": 291,
#             "output_tokens": 2312,
#             "total_tokens": 2603
#         },
#         "request_usage": {
#             "successful_requests": 2,
#             "failed_requests": 0,
#             "total_requests": 2
#         },
#         "tokens_per_second": 480,
#         "requests_per_minute": 22
#     }
# }
# [22:39:02] [INFO] 📐 Measuring dataset column statistics:
# [22:39:02] [INFO]   |-- 🎲 column: 'patient_sampler'
# [22:39:02] [INFO]   |-- 🎲 column: 'doctor_sampler'
# [22:39:02] [INFO]   |-- 🎲 column: 'patient_id'
# [22:39:02] [INFO]   |-- 🧩 column: 'first_name'
# [22:39:02] [INFO]   |-- 🧩 column: 'last_name'
# [22:39:02] [INFO]   |-- 🧩 column: 'dob'
# [22:39:02] [INFO]   |-- 🎲 column: 'symptom_onset_date'
# [22:39:02] [INFO]   |-- 🎲 column: 'date_of_visit'
# [22:39:02] [INFO]   |-- 🧩 column: 'physician'
# [22:39:02] [INFO]   |-- 📝 column: 'physician_notes'
# [22:39:02] [INFO] ☀️ Preview complete!

# %%
# Run this cell multiple times to cycle through the 2 preview records.
preview.display_sample_record()
# Out:
#
#                                                    Seed Columns
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name            ┃ Value                                                                                         ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ diagnosis       │ cervical spondylosis                                                                          │
# ├─────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ patient_summary │ I've been having a lot of pain in my neck and back. I've also been having trouble with my     │
# │                 │ balance and coordination. I've been coughing a lot and my limbs feel weak.                    │
# └─────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────┘
#
#
#                                                  Generated Columns
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name               ┃ Value                                                                                      ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ patient_sampler    │ {                                                                                          │
# │                    │     'uuid': '369383d8-807a-4974-ae25-89edbf182352',                                        │
# │                    │     'locale': 'en_US',                                                                     │
# │                    │     'first_name': 'Gloria',                                                                │
# │                    │     'last_name': 'Nolan',                                                                  │
# │                    │     'middle_name': None,                                                                   │
# │                    │     'sex': 'Female',                                                                       │
# │                    │     'street_number': '99853',                                                              │
# │                    │     'street_name': 'Duncan Plaza',                                                         │
# │                    │     'city': 'Scottmouth',                                                                  │
# │                    │     'state': 'Wyoming',                                                                    │
# │                    │     'postcode': '63455',                                                                   │
# │                    │     'age': 68,                                                                             │
# │                    │     'birth_date': '1957-05-10',                                                            │
# │                    │     'country': 'Saint Lucia',                                                              │
# │                    │     'marital_status': 'separated',                                                         │
# │                    │     'education_level': 'secondary_education',                                              │
# │                    │     'unit': '',                                                                            │
# │                    │     'occupation': 'Media buyer',                                                           │
# │                    │     'phone_number': '001-912-223-1348',                                                    │
# │                    │     'bachelors_field': 'no_degree'                                                         │
# │                    │ }                                                                                          │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ doctor_sampler     │ {                                                                                          │
# │                    │     'uuid': '9b176750-7e43-45e3-8f99-92059e34d90f',                                        │
# │                    │     'locale': 'en_US',                                                                     │
# │                    │     'first_name': 'Monica',                                                                │
# │                    │     'last_name': 'Jones',                                                                  │
# │                    │     'middle_name': None,                                                                   │
# │                    │     'sex': 'Female',                                                                       │
# │                    │     'street_number': '74562',                                                              │
# │                    │     'street_name': 'Emma Ranch',                                                           │
# │                    │     'city': 'South Timothy',                                                               │
# │                    │     'state': 'Connecticut',                                                                │
# │                    │     'postcode': '40566',                                                                   │
# │                    │     'age': 100,                                                                            │
# │                    │     'birth_date': '1925-04-17',                                                            │
# │                    │     'country': 'British Virgin Islands',                                                   │
# │                    │     'marital_status': 'never_married',                                                     │
# │                    │     'education_level': 'secondary_education',                                              │
# │                    │     'unit': '',                                                                            │
# │                    │     'occupation': 'Chartered management accountant',                                       │
# │                    │     'phone_number': '226-343-7560x446',                                                    │
# │                    │     'bachelors_field': 'no_degree'                                                         │
# │                    │ }                                                                                          │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ patient_id         │ PT-2933FC66                                                                                │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ symptom_onset_date │ 2024-03-27                                                                                 │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ date_of_visit      │ 2024-03-31                                                                                 │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ first_name         │ Gloria                                                                                     │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ last_name          │ Nolan                                                                                      │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ dob                │ 1957-05-10                                                                                 │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ physician          │ Dr. Jones                                                                                  │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ physician_notes    │ **Patient:** Gloria Nolan                                                                  │
# │                    │ **DOB:** 1958-07-12 (Age: 65)                                                              │
# │                    │ **Visit:** 2024-03-31                                                                      │
# │                    │ **Reason for Visit:** Follow-up for cervical spondylosis exacerbation (2024-03-27 onset).  │
# │                    │                                                                                            │
# │                    │ **History of Present Illness (HPI):**                                                      │
# │                    │ - **Neck/Back Pain:** Constant, 7/10 intensity, bilateral cervical/thoracic. Worse with    │
# │                    │ movement; no relief with rest.                                                             │
# │                    │ - **Neurological:** New-onset balance issues (trips when turning), hand tremors (loss of   │
# │                    │ fine motor control), generalized weakness (difficulty lifting objects).                    │
# │                    │ - **Respiratory:** Chronic cough (3+ days/week), non-productive. Denies dyspnea.           │
# │                    │ - **Systemic:** Reports fatigue (recent), denies fever/chills. Denies urinary incontinence │
# │                    │ or bowel changes.                                                                          │
# │                    │ - **Duration:** Symptoms began 2024-03-27; followed 4 days later by cough/weakness. No     │
# │                    │ prior similar episodes.                                                                    │
# │                    │ - **Prior Management:** Treated for cervical spondylosis with PT/analgesics (2023); no     │
# │                    │ imaging since.                                                                             │
# │                    │                                                                                            │
# │                    │ **Past Medical History (PMH):**                                                            │
# │                    │ - Hypertension (controlled), Osteoarthritis (cervical/lumbar).                             │
# │                    │                                                                                            │
# │                    │ **Medications:**                                                                           │
# │                    │ - Lisinopril 10mg DAILY, Ibuprofen 600mg TID PRN.                                          │
# │                    │                                                                                            │
# │                    │ **Allergies:** NKDA.                                                                       │
# │                    │                                                                                            │
# │                    │ **Review of Systems (ROS):**                                                               │
# │                    │ - **Neurological:** Tremors, balance impairment (new), weakness (all limbs).               │
# │                    │ - **Musculoskeletal:** Chronic neck/back pain (current exacerbation).                      │
# │                    │ - **Respiratory:** Cough (new), no SOB.                                                    │
# │                    │ - **Other:** Fatigue (new).                                                                │
# │                    │                                                                                            │
# │                    │ **Physical Exam:**                                                                         │
# │                    │ - **Vitals:** BP 148/92, HR 82, RR 16, SpO₂ 98% RA.                                        │
# │                    │ - **Neck:** Limited ROM (flexion/extension), tenderness C5-T1.                             │
# │                    │ - **Neurological:**                                                                        │
# │                    │   - Strength: 4/5 in all extremities (vs. 5/5 baseline).                                   │
# │                    │   - Reflexes: 2+ symmetric.                                                                │
# │                    │   - Positive Romberg’s test (unsteadiness with eyes closed).                               │
# │                    │   - Tremors noted in hands (action-type).                                                  │
# │                    │ - **Respiratory:** Clear to auscultation bilaterally.                                      │
# │                    │ - **Other:** No lymphatic or dermatological abnormalities.                                 │
# │                    │                                                                                            │
# │                    │ **Assessment:**                                                                            │
# │                    │ 1. **Cervical spondylosis with acute exacerbation** (pain + neurologic symptoms).          │
# │                    │ 2. **New neurologic findings:** Tremors, balance impairment, weakness (suggestive of       │
# │                    │ possible myelopathy or radiculopathy progression).                                         │
# │                    │ 3. **Acute upper respiratory symptoms:** Cough (likely viral, but workup pending).         │
# │                    │ 4. **Fatigue:** Possibly secondary to chronic condition or acute illness.                  │
# │                    │                                                                                            │
# │                    │ **Plan:**                                                                                  │
# │                    │ 1. **Imaging:** Order urgent cervical spine MRI (cervical spine, brain) to evaluate for    │
# │                    │ myelopathy/compression.                                                                    │
# │                    │ 2. **Neurology Consultation:** Refer to neurology for tremor/weakness evaluation.          │
# │                    │ 3. **Medication Adjustments:**                                                             │
# │                    │    - Continue NSAIDs for pain; rotate to naproxen 500mg BID for better efficacy.           │
# │                    │    - Consider low-dose gabapentin 100mg TID *if pain persists* (avoid opioids).            │
# │                    │ 4. **Supportive Care:**                                                                    │
# │                    │    - Refer to PT for gait training/strengthening (focus on cervical stability).            │
# │                    │    - Prescribe cough suppressant (dextromethorphan) for symptomatic relief.                │
# │                    │ 5. **Follow-up:**                                                                          │
# │                    │    - Return in 7 days for MRI results and neurology consult summary.                       │
# │                    │    - Rule out infection if cough persists beyond 10 days.                                  │
# │                    │                                                                                            │
# │                    │ **Patient Education:**                                                                     │
# │                    │ - Emphasized avoiding neck strain (no heavy lifting, maintain neutral posture).            │
# │                    │ - Instructed to avoid driving until balance assessed.                                      │
# │                    │ - Discussed fall prevention strategies (clear walkways, use assistive devices).            │
# │                    │                                                                                            │
# │                    │ **Patient Concerns Addressed:**                                                            │
# │                    │ - Marked anxiety about "weak limbs" and falling; reassurance provided regarding urgency of │
# │                    │ workup.                                                                                    │
# │                    │ - Cough discussed as likely unrelated to cervical pathology but requires monitoring.       │
# │                    │                                                                                            │
# │                    │ **Plan Summary:**                                                                          │
# │                    │ Urgent imaging + neurology consult to rule out serious neurologic progression. Symptomatic │
# │                    │ management focused on pain, cough, and fall risk.                                          │
# │                    │                                                                                            │
# │                    │ **Note:** *No red flags for infection, stroke, or acute trauma. Neurologic findings        │
# │                    │ warrant prompt attention to prevent functional decline.*                                   │
# └────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────┘
#
#                                                     [index: 0]

# %%
# The preview dataset is available as a pandas DataFrame.
preview.dataset
# Out:
#               diagnosis                                    patient_summary  \
# 0  cervical spondylosis  I've been having a lot of pain in my neck and ...
# 1              impetigo  I have a rash on my face that is getting worse...
#
#                                      patient_sampler  \
# 0  {'uuid': '369383d8-807a-4974-ae25-89edbf182352...
# 1  {'uuid': '72435a7d-7022-42d5-917c-6d3ba1be5950...
#
#                                       doctor_sampler   patient_id  \
# 0  {'uuid': '9b176750-7e43-45e3-8f99-92059e34d90f...  PT-2933FC66
# 1  {'uuid': '46965e47-77f2-49b4-9c45-0a4640236e19...  PT-FA89BCED
#
#   symptom_onset_date date_of_visit first_name last_name         dob  \
# 0         2024-03-27    2024-03-31     Gloria     Nolan  1957-05-10
# 1         2024-08-28    2024-09-13    Kenneth   Andrews  1972-04-28
#
#     physician                                    physician_notes
# 0   Dr. Jones  **Patient:** Gloria Nolan  \n**DOB:** 1958-07-...
# 1  Dr. Howell  **Visit: Kenneth Andrews – 2024-09-13**  \n**P...

# %% [markdown]
# ### 📊 Analyze the generated data
#
# - Data Designer automatically generates a basic statistical analysis of the generated data.
#
# - This analysis is available via the `analysis` property of generation result objects.

# %%
# Print the analysis as a table.
preview.analysis.to_report()
# Out:
# ──────────────────────────────────────── 🎨 Data Designer Dataset Profile ─────────────────────────────────────────
#
#
#                                                  Dataset Overview
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ number of records               ┃ number of columns               ┃ percent complete records                    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 2                               │ 10                              │ 100.0%                                      │
# └─────────────────────────────────┴─────────────────────────────────┴─────────────────────────────────────────────┘
#
#
#                                                 🎲 Sampler Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                   ┃       data type ┃             number unique values ┃               sampler type ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ patient_sampler               │            dict │                       2 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ doctor_sampler                │            dict │                       2 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ patient_id                    │          string │                       2 (100.0%) │                       uuid │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ symptom_onset_date            │          string │                       2 (100.0%) │                   datetime │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ date_of_visit                 │          string │                       2 (100.0%) │                  timedelta │
# └───────────────────────────────┴─────────────────┴──────────────────────────────────┴────────────────────────────┘
#
#
#                                                 📝 LLM-Text Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                       ┃               ┃                            ┃     prompt tokens ┃      completion tokens ┃
# ┃ column name           ┃     data type ┃       number unique values ┃        per record ┃             per record ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ physician_notes       │        string │                 2 (100.0%) │     122.0 +/- 4.0 │       1082.5 +/- 122.3 │
# └───────────────────────┴───────────────┴────────────────────────────┴───────────────────┴────────────────────────┘
#
#
#                                                🧩 Expression Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                    ┃                 data type ┃                               number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ first_name                     │                    string │                                         2 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ last_name                      │                    string │                                         2 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ dob                            │                    string │                                         2 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ physician                      │                    string │                                         2 (100.0%) │
# └────────────────────────────────┴───────────────────────────┴────────────────────────────────────────────────────┘
#
#
# ╭────────────────────────────────────────────────── Table Notes ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  1. All token statistics are based on a sample of max(1000, len(dataset)) records.                              │
# │  2. Tokens are calculated using tiktoken's cl100k_base tokenizer.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### 🆙 Scale up!
#
# - Happy with your preview data?
#
# - Use the `create` method to submit larger Data Designer generation jobs.

# %%
results = data_designer.create(config_builder, num_records=10, dataset_name="tutorial-3")
# Out:
# [22:39:02] [INFO] 🎨 Creating Data Designer dataset
# [22:39:02] [INFO] ✅ Validation passed
# [22:39:02] [INFO] ⛓️ Sorting column configs into a Directed Acyclic Graph
# [22:39:02] [INFO] 🩺 Running health checks for models...
# [22:39:02] [INFO]   |-- 👀 Checking 'nvidia/nemotron-3-nano-30b-a3b' in provider named 'nvidia' for model alias 'nemotron-nano-v3'...
# [22:39:02] [INFO]   |-- ✅ Passed!
# [22:39:02] [INFO] ⏳ Processing batch 1 of 1
# [22:39:02] [INFO] 🌱 Sampling 10 records from seed dataset
# [22:39:02] [INFO]   |-- seed dataset size: 820 records
# [22:39:02] [INFO]   |-- sampling strategy: ordered
# [22:39:02] [INFO] 🎲 Preparing samplers to generate 10 records across 5 columns
# [22:39:02] [INFO] (💾 + 💾) Concatenating 2 datasets
# [22:39:02] [INFO] 🧩 Generating column `first_name` from expression
# [22:39:02] [INFO] 🧩 Generating column `last_name` from expression
# [22:39:02] [INFO] 🧩 Generating column `dob` from expression
# [22:39:02] [INFO] 🧩 Generating column `physician` from expression
# [22:39:02] [INFO] llm-text model configuration for generating column 'physician_notes'
# [22:39:02] [INFO]   |-- model: 'nvidia/nemotron-3-nano-30b-a3b'
# [22:39:02] [INFO]   |-- model alias: 'nemotron-nano-v3'
# [22:39:02] [INFO]   |-- model provider: 'nvidia'
# [22:39:02] [INFO]   |-- inference parameters: generation_type=chat-completion, max_parallel_requests=4, extra_body={'chat_template_kwargs': {'enable_thinking': False}}, temperature=1.00, top_p=1.00, max_tokens=2048
# [22:39:02] [INFO] 🐙 Processing llm-text column 'physician_notes' with 4 concurrent workers
# [22:39:12] [INFO] 📊 Model usage summary:
# {
#     "nvidia/nemotron-3-nano-30b-a3b": {
#         "token_usage": {
#             "input_tokens": 1432,
#             "output_tokens": 7999,
#             "total_tokens": 9431
#         },
#         "request_usage": {
#             "successful_requests": 10,
#             "failed_requests": 0,
#             "total_requests": 10
#         },
#         "tokens_per_second": 927,
#         "requests_per_minute": 59
#     }
# }
# [22:39:12] [INFO] 📐 Measuring dataset column statistics:
# [22:39:12] [INFO]   |-- 🎲 column: 'patient_sampler'
# [22:39:12] [INFO]   |-- 🎲 column: 'doctor_sampler'
# [22:39:12] [INFO]   |-- 🎲 column: 'patient_id'
# [22:39:12] [INFO]   |-- 🧩 column: 'first_name'
# [22:39:12] [INFO]   |-- 🧩 column: 'last_name'
# [22:39:12] [INFO]   |-- 🧩 column: 'dob'
# [22:39:12] [INFO]   |-- 🎲 column: 'symptom_onset_date'
# [22:39:12] [INFO]   |-- 🎲 column: 'date_of_visit'
# [22:39:12] [INFO]   |-- 🧩 column: 'physician'
# [22:39:12] [INFO]   |-- 📝 column: 'physician_notes'

# %%
# Load the generated dataset as a pandas DataFrame.
dataset = results.load_dataset()

dataset.head()
# Out:
#                  diagnosis                                    patient_summary  \
# 0     cervical spondylosis  I've been having a lot of pain in my neck and ...
# 1                 impetigo  I have a rash on my face that is getting worse...
# 2  urinary tract infection  I have been urinating blood. I sometimes feel ...
# 3                arthritis  I have been having trouble with my muscles and...
# 4                   dengue  I have been feeling really sick. My body hurts...
#
#                                      patient_sampler  \
# 0  {'age': 35, 'bachelors_field': 'no_degree', 'b...
# 1  {'age': 76, 'bachelors_field': 'arts_humanitie...
# 2  {'age': 113, 'bachelors_field': 'arts_humaniti...
# 3  {'age': 38, 'bachelors_field': 'stem', 'birth_...
# 4  {'age': 100, 'bachelors_field': 'no_degree', '...
#
#                                       doctor_sampler   patient_id  \
# 0  {'age': 63, 'bachelors_field': 'arts_humanitie...  PT-66EC77BB
# 1  {'age': 75, 'bachelors_field': 'no_degree', 'b...  PT-681272DC
# 2  {'age': 55, 'bachelors_field': 'no_degree', 'b...  PT-902A964E
# 3  {'age': 88, 'bachelors_field': 'no_degree', 'b...  PT-F6298ED3
# 4  {'age': 61, 'bachelors_field': 'no_degree', 'b...  PT-10DFE13A
#
#   symptom_onset_date date_of_visit first_name last_name         dob  \
# 0         2024-07-16    2024-07-20      Kevin     Hodge  1990-04-07
# 1         2024-08-20    2024-08-27     Jordan     Brown  1949-01-15
# 2         2024-05-27    2024-06-16    Melanie      Hill  1913-01-12
# 3         2024-09-08    2024-09-09     Steven    Morris  1987-10-12
# 4         2024-05-07    2024-05-14       Lisa   Jackson  1925-08-22
#
#      physician                                    physician_notes
# 0   Dr. Wilcox  **Patient:** Kevin Hodge
# **DOB:** 03/15/1974...
# 1     Dr. Leon  **2024-08-27 09:45 AM**
# **Patient:** Jordan ...
# 2   Dr. Holmes  **Patient:** Melanie Hill
# **DOB:** 03/12/199...
# 3     Dr. Hall  - 09/09/2024 08:15 AM - S. Morris 56 M - New o...
# 4  Dr. Johnson  - 2024-05-14
# - Patient: Lisa Jackson (DOB: 1...

# %%
# Load the analysis results into memory.
analysis = results.load_analysis()

analysis.to_report()
# Out:
# ──────────────────────────────────────── 🎨 Data Designer Dataset Profile ─────────────────────────────────────────
#
#
#                                                  Dataset Overview
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ number of records               ┃ number of columns               ┃ percent complete records                    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 10                              │ 10                              │ 100.0%                                      │
# └─────────────────────────────────┴─────────────────────────────────┴─────────────────────────────────────────────┘
#
#
#                                                 🎲 Sampler Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                   ┃       data type ┃             number unique values ┃               sampler type ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ patient_sampler               │            dict │                      10 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ doctor_sampler                │            dict │                      10 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ patient_id                    │          string │                      10 (100.0%) │                       uuid │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ symptom_onset_date            │          string │                      10 (100.0%) │                   datetime │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ date_of_visit                 │          string │                      10 (100.0%) │                  timedelta │
# └───────────────────────────────┴─────────────────┴──────────────────────────────────┴────────────────────────────┘
#
#
#                                                 📝 LLM-Text Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                       ┃               ┃                            ┃     prompt tokens ┃      completion tokens ┃
# ┃ column name           ┃     data type ┃       number unique values ┃        per record ┃             per record ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ physician_notes       │        string │                10 (100.0%) │     118.0 +/- 5.4 │        724.0 +/- 322.8 │
# └───────────────────────┴───────────────┴────────────────────────────┴───────────────────┴────────────────────────┘
#
#
#                                                🧩 Expression Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                    ┃                 data type ┃                               number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ first_name                     │                    string │                                        10 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ last_name                      │                    string │                                        10 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ dob                            │                    string │                                        10 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ physician                      │                    string │                                        10 (100.0%) │
# └────────────────────────────────┴───────────────────────────┴────────────────────────────────────────────────────┘
#
#
# ╭────────────────────────────────────────────────── Table Notes ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  1. All token statistics are based on a sample of max(1000, len(dataset)) records.                              │
# │  2. Tokens are calculated using tiktoken's cl100k_base tokenizer.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## ⏭️ Next Steps
#
# Check out the following notebook to learn more about:
#
# - [Providing images as context](https://nvidia-nemo.github.io/DataDesigner/latest/notebooks/4-providing-images-as-context/)
