# %% [markdown]
# # 🎨 Data Designer Tutorial: Seeding Synthetic Data Generation with an External Dataset
#
# #### 📚 What you'll learn
#
# In this notebook, we will demonstrate how to seed synthetic data generation in Data Designer with an external dataset.
#
# If this is your first time using Data Designer, we recommend starting with the [first notebook](https://nvidia-nemo.github.io/DataDesigner/latest/notebooks/1-the-basics/) in this tutorial series.

# %% [markdown]
# ### 📦 Import the essentials
#
# - The `essentials` module provides quick access to the most commonly used objects.

# %%
from data_designer.essentials import (
    ChatCompletionInferenceParams,
    DataDesigner,
    DataDesignerConfigBuilder,
    ModelConfig,
)

# %% [markdown]
# ### ⚙️ Initialize the Data Designer interface
#
# - `DataDesigner` is the main object is responsible for managing the data generation process.
#
# - When initialized without arguments, the [default model providers](https://nvidia-nemo.github.io/DataDesigner/latest/concepts/models/default-model-settings/) are used.

# %%
data_designer = DataDesigner()

# %% [markdown]
# ### 🎛️ Define model configurations
#
# - Each `ModelConfig` defines a model that can be used during the generation process.
#
# - The "model alias" is used to reference the model in the Data Designer config (as we will see below).
#
# - The "model provider" is the external service that hosts the model (see the [model config](https://nvidia-nemo.github.io/DataDesigner/latest/concepts/models/default-model-settings/) docs for more details).
#
# - By default, we use [build.nvidia.com](https://build.nvidia.com/models) as the model provider.

# %%
# This name is set in the model provider configuration.
MODEL_PROVIDER = "nvidia"

# The model ID is from build.nvidia.com.
MODEL_ID = "nvidia/nemotron-3-nano-30b-a3b"

# We choose this alias to be descriptive for our use case.
MODEL_ALIAS = "nemotron-nano-v3"

model_configs = [
    ModelConfig(
        alias=MODEL_ALIAS,
        model=MODEL_ID,
        provider=MODEL_PROVIDER,
        inference_parameters=ChatCompletionInferenceParams(
            temperature=1.0,
            top_p=1.0,
            max_tokens=2048,
            extra_body={"chat_template_kwargs": {"enable_thinking": False}},
        ),
    )
]

# %% [markdown]
# ### 🏗️ Initialize the Data Designer Config Builder
#
# - The Data Designer config defines the dataset schema and generation process.
#
# - The config builder provides an intuitive interface for building this configuration.
#
# - The list of model configs is provided to the builder at initialization.

# %%
config_builder = DataDesignerConfigBuilder(model_configs=model_configs)

# %% [markdown]
# ## 🏥 Prepare a seed dataset
#
# - For this notebook, we'll create a synthetic dataset of patient notes.
#
# - We will _seed_ the generation process with a [symptom-to-diagnosis dataset](https://huggingface.co/datasets/gretelai/symptom_to_diagnosis).
#
# - We already have the dataset downloaded in the [data](../data) directory of this repository.
#
# <br>
#
# > 🌱 **Why use a seed dataset?**
# >
# > - Seed datasets let you steer the generation process by providing context that is specific to your use case.
# >
# > - Seed datasets are also an excellent way to inject real-world diversity into your synthetic data.
# >
# > - During generation, prompt templates can reference any of the seed dataset fields.

# %%
# Download sample dataset from Github
import urllib.request

url = "https://raw.githubusercontent.com/NVIDIA/GenerativeAIExamples/refs/heads/main/nemo/NeMo-Data-Designer/data/gretelai_symptom_to_diagnosis.csv"
local_filename, _ = urllib.request.urlretrieve(url, "gretelai_symptom_to_diagnosis.csv")

# Seed datasets are passed as reference objects to the config builder.
seed_dataset_reference = data_designer.make_seed_reference_from_file(local_filename)

config_builder.with_seed_dataset(seed_dataset_reference)
# Out:
# DataDesignerConfigBuilder(
#     seed_dataset: 'gretelai_symptom_to_diagnosis.csv'
#     seed_dataset_columns: ['diagnosis', 'patient_summary']
# )

# %% [markdown]
# ## 🎨 Designing our synthetic patient notes dataset
#
# - Here we use `add_column` with keyword arguments (rather than imported config objects).
#
# - Generally, we recommend using concrete objects, but this is a convenient shorthand.
#
# - **Note**: The prompt template can reference fields from our seed dataset:
#   - `{{ diagnosis }}` - the medical diagnosis from the seed data
#   - `{{ patient_summary }}` - the symptom description from the seed data

# %%
config_builder.add_column(
    name="patient_sampler",
    column_type="sampler",
    sampler_type="person_from_faker",
)

config_builder.add_column(
    name="doctor_sampler",
    column_type="sampler",
    sampler_type="person_from_faker",
)

config_builder.add_column(
    name="patient_id",
    column_type="sampler",
    sampler_type="uuid",
    params={
        "prefix": "PT-",
        "short_form": True,
        "uppercase": True,
    },
)

config_builder.add_column(
    name="first_name",
    column_type="expression",
    expr="{{ patient_sampler.first_name}}",
)

config_builder.add_column(
    name="last_name",
    column_type="expression",
    expr="{{ patient_sampler.last_name }}",
)


config_builder.add_column(
    name="dob",
    column_type="expression",
    expr="{{ patient_sampler.birth_date }}",
)

config_builder.add_column(
    name="symptom_onset_date",
    column_type="sampler",
    sampler_type="datetime",
    params={"start": "2024-01-01", "end": "2024-12-31"},
)

config_builder.add_column(
    name="date_of_visit",
    column_type="sampler",
    sampler_type="timedelta",
    params={"dt_min": 1, "dt_max": 30, "reference_column_name": "symptom_onset_date"},
)

config_builder.add_column(
    name="physician",
    column_type="expression",
    expr="Dr. {{ doctor_sampler.last_name }}",
)

config_builder.add_column(
    name="physician_notes",
    column_type="llm-text",
    prompt="""\
You are a primary-care physician who just had an appointment with {{ first_name }} {{ last_name }},
who has been struggling with symptoms from {{ diagnosis }} since {{ symptom_onset_date }}.
The date of today's visit is {{ date_of_visit }}.

{{ patient_summary }}

Write careful notes about your visit with {{ first_name }},
as Dr. {{ doctor_sampler.first_name }} {{ doctor_sampler.last_name }}.

Format the notes as a busy doctor might.
Respond with only the notes, no other text.
""",
    model_alias=MODEL_ALIAS,
)

config_builder.validate()
# Out:
# [22:44:39] [INFO] ✅ Validation passed
# DataDesignerConfigBuilder(
#     seed_dataset: 'gretelai_symptom_to_diagnosis.csv'
#     seed_dataset_columns: ['diagnosis', 'patient_summary']
#     sampler_columns: [
#         "patient_sampler",
#         "doctor_sampler",
#         "patient_id",
#         "symptom_onset_date",
#         "date_of_visit"
#     ]
#     llm_text_columns: ['physician_notes']
#     expression_columns: [
#         "first_name",
#         "last_name",
#         "dob",
#         "physician"
#     ]
# )

# %% [markdown]
# ### 🔁 Iteration is key – preview the dataset!
#
# 1. Use the `preview` method to generate a sample of records quickly.
#
# 2. Inspect the results for quality and format issues.
#
# 3. Adjust column configurations, prompts, or parameters as needed.
#
# 4. Re-run the preview until satisfied.

# %%
preview = data_designer.preview(config_builder, num_records=2)
# Out:
# [22:44:39] [INFO] 🔁 Preview generation in progress
# [22:44:39] [INFO] ✅ Validation passed
# [22:44:39] [INFO] ⛓️ Sorting column configs into a Directed Acyclic Graph
# [22:44:39] [INFO] 🩺 Running health checks for models...
# [22:44:39] [INFO]   |-- 👀 Checking 'nvidia/nemotron-3-nano-30b-a3b' in provider named 'nvidia' for model alias 'nemotron-nano-v3'...
# [22:44:40] [INFO]   |-- ✅ Passed!
# [22:44:40] [INFO] 🌱 Sampling 2 records from seed dataset
# [22:44:40] [INFO]   |-- seed dataset size: 820 records
# [22:44:40] [INFO]   |-- sampling strategy: ordered
# [22:44:40] [INFO] 🎲 Preparing samplers to generate 2 records across 5 columns
# [22:44:40] [INFO] (💾 + 💾) Concatenating 2 datasets
# [22:44:40] [INFO] 🧩 Generating column `first_name` from expression
# [22:44:40] [INFO] 🧩 Generating column `last_name` from expression
# [22:44:40] [INFO] 🧩 Generating column `dob` from expression
# [22:44:40] [INFO] 🧩 Generating column `physician` from expression
# [22:44:40] [INFO] Preparing llm-text column generation
# [22:44:40] [INFO]   |-- column name: 'physician_notes'
# [22:44:40] [INFO]   |-- model config:
# {
#     "alias": "nemotron-nano-v3",
#     "model": "nvidia/nemotron-3-nano-30b-a3b",
#     "inference_parameters": {
#         "generation_type": "chat-completion",
#         "max_parallel_requests": 4,
#         "timeout": null,
#         "extra_body": {
#             "chat_template_kwargs": {
#                 "enable_thinking": false
#             }
#         },
#         "temperature": 1.0,
#         "top_p": 1.0,
#         "max_tokens": 2048
#     },
#     "provider": "nvidia"
# }
# [22:44:40] [INFO] 🐙 Processing llm-text column 'physician_notes' with 4 concurrent workers
# [22:44:44] [INFO] 📊 Model usage summary:
# {
#     "nvidia/nemotron-3-nano-30b-a3b": {
#         "token_usage": {
#             "input_tokens": 291,
#             "output_tokens": 2453,
#             "total_tokens": 2744
#         },
#         "request_usage": {
#             "successful_requests": 2,
#             "failed_requests": 0,
#             "total_requests": 2
#         },
#         "tokens_per_second": 668,
#         "requests_per_minute": 29
#     }
# }
# [22:44:44] [INFO] 📐 Measuring dataset column statistics:
# [22:44:44] [INFO]   |-- 🌱 column: 'diagnosis'
# [22:44:44] [INFO]   |-- 🌱 column: 'patient_summary'
# [22:44:44] [INFO]   |-- 🎲 column: 'patient_sampler'
# [22:44:44] [INFO]   |-- 🎲 column: 'doctor_sampler'
# [22:44:44] [INFO]   |-- 🎲 column: 'patient_id'
# [22:44:44] [INFO]   |-- 🧩 column: 'first_name'
# [22:44:44] [INFO]   |-- 🧩 column: 'last_name'
# [22:44:44] [INFO]   |-- 🧩 column: 'dob'
# [22:44:44] [INFO]   |-- 🎲 column: 'symptom_onset_date'
# [22:44:44] [INFO]   |-- 🎲 column: 'date_of_visit'
# [22:44:44] [INFO]   |-- 🧩 column: 'physician'
# [22:44:44] [INFO]   |-- 📝 column: 'physician_notes'
# [22:44:44] [INFO] 🎉 Preview complete!

# %%
# Run this cell multiple times to cycle through the 2 preview records.
preview.display_sample_record()
# Out:
#
#                                                    Seed Columns
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name            ┃ Value                                                                                         ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ diagnosis       │ cervical spondylosis                                                                          │
# ├─────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ patient_summary │ I've been having a lot of pain in my neck and back. I've also been having trouble with my     │
# │                 │ balance and coordination. I've been coughing a lot and my limbs feel weak.                    │
# └─────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────┘
#
#
#                                                  Generated Columns
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name               ┃ Value                                                                                      ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ patient_sampler    │ {                                                                                          │
# │                    │     'uuid': '3328ff21-45a0-4d28-bb61-e12a4750e12c',                                        │
# │                    │     'locale': 'en_US',                                                                     │
# │                    │     'first_name': 'Amy',                                                                   │
# │                    │     'last_name': 'Le',                                                                     │
# │                    │     'middle_name': None,                                                                   │
# │                    │     'sex': 'Female',                                                                       │
# │                    │     'street_number': '4607',                                                               │
# │                    │     'street_name': 'Andrews Branch',                                                       │
# │                    │     'city': 'New Thomas',                                                                  │
# │                    │     'state': 'Tennessee',                                                                  │
# │                    │     'postcode': '10601',                                                                   │
# │                    │     'age': 63,                                                                             │
# │                    │     'birth_date': '1962-05-08',                                                            │
# │                    │     'country': 'Gabon',                                                                    │
# │                    │     'marital_status': 'separated',                                                         │
# │                    │     'education_level': 'secondary_education',                                              │
# │                    │     'unit': '',                                                                            │
# │                    │     'occupation': 'Product/process development scientist',                                 │
# │                    │     'phone_number': '001-986-597-4894x0597',                                               │
# │                    │     'bachelors_field': 'no_degree'                                                         │
# │                    │ }                                                                                          │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ doctor_sampler     │ {                                                                                          │
# │                    │     'uuid': '2b86f3cd-c9b5-442b-8a1d-bea03c29a887',                                        │
# │                    │     'locale': 'en_US',                                                                     │
# │                    │     'first_name': 'Laura',                                                                 │
# │                    │     'last_name': 'Young',                                                                  │
# │                    │     'middle_name': None,                                                                   │
# │                    │     'sex': 'Female',                                                                       │
# │                    │     'street_number': '1810',                                                               │
# │                    │     'street_name': 'Rodriguez Ports',                                                      │
# │                    │     'city': 'South Clinton',                                                               │
# │                    │     'state': 'Florida',                                                                    │
# │                    │     'postcode': '81624',                                                                   │
# │                    │     'age': 66,                                                                             │
# │                    │     'birth_date': '1959-08-05',                                                            │
# │                    │     'country': 'Greece',                                                                   │
# │                    │     'marital_status': 'never_married',                                                     │
# │                    │     'education_level': 'bachelors',                                                        │
# │                    │     'unit': '',                                                                            │
# │                    │     'occupation': 'Metallurgist',                                                          │
# │                    │     'phone_number': '+1-510-269-7183x441',                                                 │
# │                    │     'bachelors_field': 'stem'                                                              │
# │                    │ }                                                                                          │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ patient_id         │ PT-FB1E12A9                                                                                │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ symptom_onset_date │ 2024-12-12                                                                                 │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ date_of_visit      │ 2025-01-09                                                                                 │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ first_name         │ Amy                                                                                        │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ last_name          │ Le                                                                                         │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ dob                │ 1962-05-08                                                                                 │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ physician          │ Dr. Young                                                                                  │
# ├────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ physician_notes    │ **Patient:** Amy Le                                                                        │
# │                    │ **DOB:** [Redacted]                                                                        │
# │                    │ **MRN:** [Redacted]                                                                        │
# │                    │ **Visit Date:** 2025-01-09                                                                 │
# │                    │ **Provider:** Laura Young, MD                                                              │
# │                    │                                                                                            │
# │                    │ ---                                                                                        │
# │                    │                                                                                            │
# │                    │ **CC:** “Neck and back pain, worsening balance, frequent coughing, limb weakness.”         │
# │                    │                                                                                            │
# │                    │ **HPI:**                                                                                   │
# │                    │ - 57‑year‑old female with known cervical spondylosis (diagnosed 2024‑12‑12) reports        │
# │                    │ progressive neck and upper/mid‑back pain over past 3 weeks; pain is constant, described as │
# │                    │ dull‑achy, worsens with neck flexion/extension, improves briefly with rest.                │
# │                    │ - New‑onset lower extremity weakness (gradual, bilateral), particularly difficulty         │
# │                    │ climbing stairs and rising from a seated position.                                         │
# │                    │ - Frequent coughing episodes noted; patient reports increase in sputum volume,             │
# │                    │ non‑purulent, no hemoptysis.                                                               │
# │                    │ - Balance impairment: occasional unsteady gait, need to hold onto furniture; denies falls. │
# │                    │ - No recent upper‑respiratory infection, fever, chills, weight loss, or dysphagia.         │
# │                    │ - Medications: currently on low‑dose tramadol PRN, physical therapy 2×/wk, vitamin D       │
# │                    │ supplementation.                                                                           │
# │                    │ - Past medical history: hypertension, cervical spondylosis, osteoporosis                   │
# │                    │ (post‑menopausal).                                                                         │
# │                    │ - Social: former smoker (10 pack‑yr quit 10 yr ago), lives alone.                          │
# │                    │                                                                                            │
# │                    │ **Review of Systems (pertinent):**                                                         │
# │                    │ - **General:** fatigue, mild weight loss (≈3 kg) over 2 months.                            │
# │                    │ - **HEENT:** cough productive, no sore throat, no nasal congestion.                        │
# │                    │ - **Neurologic:** weakness in both upper and lower extremities (MRC 4/5 proximal, 3/5      │
# │                    │ distal), decreased sensation to light touch in C5‑C6 dermatomes, occasional tingling, gait │
# │                    │ instability.                                                                               │
# │                    │ - **Respiratory:** chronic cough, no wheeze, no shortness of breath at rest, dyspnea on    │
# │                    │ exertion.                                                                                  │
# │                    │                                                                                            │
# │                    │ **Physical Exam:**                                                                         │
# │                    │ - **Vital Signs:** BP 138/84 mmHg, HR 78 bpm, RR 16, SpO₂ 96% RA, Temp 36.8 °C.            │
# │                    │ - **General:** Alert, oriented ×3, appears mildly fatigued.                                │
# │                    │ - **Neck:** Limited flexion/extension due to pain, tender paraspinal muscles C3‑C7. No     │
# │                    │ palpable masses.                                                                           │
# │                    │ - **Neurologic:**                                                                          │
# │                    │   - Strength: Upper extremities 4/5 (proximal) / 4+/5 (distal), Lower extremities 3/5      │
# │                    │ (proximal) / 3+/5 (distal).                                                                │
# │                    │   - Deep tendon reflexes: 2+ throughout, hyperreflexic (+) in lower limbs.                 │
# │                    │   - Positive Romberg; gait: wide base, requires assistance.                                │
# │                    │   - Sensation: decreased pinprick and light touch in C5‑C6 dermatomes bilaterally.         │
# │                    │   - No clonus or Babinski.                                                                 │
# │                    │ - **Respiratory:** Clear breath sounds bilaterally, mild crackles at bilateral bases.      │
# │                    │ - **Cardiovascular:** Regular rate/rhythm, no murmurs.                                     │
# │                    │ - **Extremities:** No edema, normal pulses.                                                │
# │                    │                                                                                            │
# │                    │ **Assessment/Impression:**                                                                 │
# │                    │ 1. **Cervical spondylosis with progressive myelopathic signs** – worsening neck pain,      │
# │                    │ upper extremity weakness, gait disturbance, hyperreflexia.                                 │
# │                    │ 2. **Upper respiratory irritation** – chronic cough, likely secondary to airway irritation │
# │                    │ from cervical pathology or mild bronchospasm.                                              │
# │                    │ 3. **Generalized weakness/fatigue** – may be secondary to chronic pain, anemia (pending    │
# │                    │ labs), or underlying pathology (e.g., vertebral artery compromise).                        │
# │                    │ 4. **Risk of functional decline** – balance impairment, need for supportive device.        │
# │                    │                                                                                            │
# │                    │ **Plan:**                                                                                  │
# │                    │ - **Imaging:** Order cervical spine MRI with contrast to assess canal stenosis, cord       │
# │                    │ compression, and degenerative changes.                                                     │
# │                    │ - **Referral:** Neurosurgery consult for surgical evaluation if MRI demonstrates           │
# │                    │ significant canal narrowing/ compressive lesion.                                           │
# │                    │ - **Physical Therapy:** Continue PT focusing on cervical stabilization and gait training;  │
# │                    │ add vestibular rehab for balance.                                                          │
# │                    │ - **Medication:** Continue tramadol PRN; consider short course of a NSAID (e.g., ibuprofen │
# │                    │ 400 mg TID) for inflammatory component, monitor renal function.                            │
# │                    │ - **Cough:** Evaluate for GERD or post‑nasal drip; consider chest X‑ray to rule out        │
# │                    │ interstitial involvement; if persistent, refer to ENT/pulmonary for further workup.        │
# │                    │ - **Labs:** CBC, CMP, TSH, Vitamin D, iron studies, CRP, ESR. Review renal function before │
# │                    │ NSAID initiation.                                                                          │
# │                    │ - **Monitoring:** Follow‑up in 2 weeks to review imaging results and adjust management;    │
# │                    │ arrange occupational therapy home safety assessment.                                       │
# │                    │ - **Patient Education:** Discuss signs of worsening neurological deficit (e.g., new        │
# │                    │ weakness, urinary incontinence, severe gait instability) and advise immediate ED           │
# │                    │ presentation if they occur.                                                                │
# │                    │                                                                                            │
# │                    │ **Follow‑up:** Return visit 2025‑01‑23 (or sooner if symptoms acutely worsen).             │
# │                    │                                                                                            │
# │                    │ ---                                                                                        │
# │                    │ *Note: This encounter documented for continuity of care; further updates to be recorded as │
# │                    │ needed.*                                                                                   │
# └────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────┘
#
#                                                     [index: 0]

# %%
# The preview dataset is available as a pandas DataFrame.
preview.dataset
# Out:
#               diagnosis                                    patient_summary  \
# 0  cervical spondylosis  I've been having a lot of pain in my neck and ...
# 1              impetigo  I have a rash on my face that is getting worse...
#
#                                      patient_sampler  \
# 0  {'uuid': '3328ff21-45a0-4d28-bb61-e12a4750e12c...
# 1  {'uuid': '5d860060-b9da-4a24-a954-e804fa6d1b92...
#
#                                       doctor_sampler   patient_id  \
# 0  {'uuid': '2b86f3cd-c9b5-442b-8a1d-bea03c29a887...  PT-FB1E12A9
# 1  {'uuid': '531b9e05-2c3b-45cf-8580-3103d3553845...  PT-C2C586B2
#
#   symptom_onset_date date_of_visit first_name last_name         dob  \
# 0         2024-12-12    2025-01-09        Amy        Le  1962-05-08
# 1         2024-03-17    2024-04-12      Pedro    Jensen  2007-09-24
#
#     physician                                    physician_notes
# 0   Dr. Young  **Patient:** Amy Le  \n**DOB:** [Redacted]  \n...
# 1  Dr. Thomas  **APPT DATE:** 2024-04-12 | **PATIENT:** 34M, ...

# %% [markdown]
# ### 📊 Analyze the generated data
#
# - Data Designer automatically generates a basic statistical analysis of the generated data.
#
# - This analysis is available via the `analysis` property of generation result objects.

# %%
# Print the analysis as a table.
preview.analysis.to_report()
# Out:
# ──────────────────────────────────────── 🎨 Data Designer Dataset Profile ─────────────────────────────────────────
#
#
#                                                  Dataset Overview
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ number of records               ┃ number of columns               ┃ percent complete records                    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 2                               │ 12                              │ 100.0%                                      │
# └─────────────────────────────────┴─────────────────────────────────┴─────────────────────────────────────────────┘
#
#
#                                               🌱 Seed-Dataset Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                          ┃               data type ┃                           number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ diagnosis                            │                  string │                                     2 (100.0%) │
# ├──────────────────────────────────────┼─────────────────────────┼────────────────────────────────────────────────┤
# │ patient_summary                      │                  string │                                     2 (100.0%) │
# └──────────────────────────────────────┴─────────────────────────┴────────────────────────────────────────────────┘
#
#
#                                                 🎲 Sampler Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                   ┃       data type ┃             number unique values ┃               sampler type ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ patient_sampler               │            dict │                       2 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ doctor_sampler                │            dict │                       2 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ patient_id                    │          string │                       2 (100.0%) │                       uuid │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ symptom_onset_date            │          string │                       2 (100.0%) │                   datetime │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ date_of_visit                 │          string │                       2 (100.0%) │                  timedelta │
# └───────────────────────────────┴─────────────────┴──────────────────────────────────┴────────────────────────────┘
#
#
#                                                 📝 LLM-Text Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                       ┃               ┃                            ┃     prompt tokens ┃      completion tokens ┃
# ┃ column name           ┃     data type ┃       number unique values ┃        per record ┃             per record ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ physician_notes       │        string │                 2 (100.0%) │     122.0 +/- 4.0 │        1153.0 +/- 22.6 │
# └───────────────────────┴───────────────┴────────────────────────────┴───────────────────┴────────────────────────┘
#
#
#                                                🧩 Expression Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                    ┃                 data type ┃                               number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ first_name                     │                    string │                                         2 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ last_name                      │                    string │                                         2 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ dob                            │                    string │                                         2 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ physician                      │                    string │                                         2 (100.0%) │
# └────────────────────────────────┴───────────────────────────┴────────────────────────────────────────────────────┘
#
#
# ╭────────────────────────────────────────────────── Table Notes ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  1. All token statistics are based on a sample of max(1000, len(dataset)) records.                              │
# │  2. Tokens are calculated using tiktoken's cl100k_base tokenizer.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### 🆙 Scale up!
#
# - Happy with your preview data?
#
# - Use the `create` method to submit larger Data Designer generation jobs.

# %%
results = data_designer.create(config_builder, num_records=10, dataset_name="tutorial-3")
# Out:
# [22:44:44] [INFO] 🎨 Creating Data Designer dataset
# [22:44:44] [INFO] ✅ Validation passed
# [22:44:44] [INFO] ⛓️ Sorting column configs into a Directed Acyclic Graph
# [22:44:44] [INFO] 🩺 Running health checks for models...
# [22:44:44] [INFO]   |-- 👀 Checking 'nvidia/nemotron-3-nano-30b-a3b' in provider named 'nvidia' for model alias 'nemotron-nano-v3'...
# [22:44:44] [INFO]   |-- ✅ Passed!
# [22:44:44] [INFO] ⏳ Processing batch 1 of 1
# [22:44:44] [INFO] 🌱 Sampling 10 records from seed dataset
# [22:44:44] [INFO]   |-- seed dataset size: 820 records
# [22:44:44] [INFO]   |-- sampling strategy: ordered
# [22:44:44] [INFO] 🎲 Preparing samplers to generate 10 records across 5 columns
# [22:44:44] [INFO] (💾 + 💾) Concatenating 2 datasets
# [22:44:44] [INFO] 🧩 Generating column `first_name` from expression
# [22:44:44] [INFO] 🧩 Generating column `last_name` from expression
# [22:44:44] [INFO] 🧩 Generating column `dob` from expression
# [22:44:44] [INFO] 🧩 Generating column `physician` from expression
# [22:44:44] [INFO] Preparing llm-text column generation
# [22:44:44] [INFO]   |-- column name: 'physician_notes'
# [22:44:44] [INFO]   |-- model config:
# {
#     "alias": "nemotron-nano-v3",
#     "model": "nvidia/nemotron-3-nano-30b-a3b",
#     "inference_parameters": {
#         "generation_type": "chat-completion",
#         "max_parallel_requests": 4,
#         "timeout": null,
#         "extra_body": {
#             "chat_template_kwargs": {
#                 "enable_thinking": false
#             }
#         },
#         "temperature": 1.0,
#         "top_p": 1.0,
#         "max_tokens": 2048
#     },
#     "provider": "nvidia"
# }
# [22:44:44] [INFO] 🐙 Processing llm-text column 'physician_notes' with 4 concurrent workers
# [22:44:53] [INFO] 📊 Model usage summary:
# {
#     "nvidia/nemotron-3-nano-30b-a3b": {
#         "token_usage": {
#             "input_tokens": 1444,
#             "output_tokens": 9313,
#             "total_tokens": 10757
#         },
#         "request_usage": {
#             "successful_requests": 10,
#             "failed_requests": 0,
#             "total_requests": 10
#         },
#         "tokens_per_second": 1232,
#         "requests_per_minute": 68
#     }
# }
# [22:44:53] [INFO] 📐 Measuring dataset column statistics:
# [22:44:53] [INFO]   |-- 🌱 column: 'diagnosis'
# [22:44:53] [INFO]   |-- 🌱 column: 'patient_summary'
# [22:44:53] [INFO]   |-- 🎲 column: 'patient_sampler'
# [22:44:53] [INFO]   |-- 🎲 column: 'doctor_sampler'
# [22:44:53] [INFO]   |-- 🎲 column: 'patient_id'
# [22:44:53] [INFO]   |-- 🧩 column: 'first_name'
# [22:44:53] [INFO]   |-- 🧩 column: 'last_name'
# [22:44:53] [INFO]   |-- 🧩 column: 'dob'
# [22:44:53] [INFO]   |-- 🎲 column: 'symptom_onset_date'
# [22:44:53] [INFO]   |-- 🎲 column: 'date_of_visit'
# [22:44:53] [INFO]   |-- 🧩 column: 'physician'
# [22:44:53] [INFO]   |-- 📝 column: 'physician_notes'

# %%
# Load the generated dataset as a pandas DataFrame.
dataset = results.load_dataset()

dataset.head()
# Out:
#                  diagnosis                                    patient_summary  \
# 0     cervical spondylosis  I've been having a lot of pain in my neck and ...
# 1                 impetigo  I have a rash on my face that is getting worse...
# 2  urinary tract infection  I have been urinating blood. I sometimes feel ...
# 3                arthritis  I have been having trouble with my muscles and...
# 4                   dengue  I have been feeling really sick. My body hurts...
#
#                                      patient_sampler  \
# 0  {'age': 72, 'bachelors_field': 'no_degree', 'b...
# 1  {'age': 97, 'bachelors_field': 'no_degree', 'b...
# 2  {'age': 104, 'bachelors_field': 'no_degree', '...
# 3  {'age': 84, 'bachelors_field': 'business', 'bi...
# 4  {'age': 39, 'bachelors_field': 'stem_related',...
#
#                                       doctor_sampler   patient_id  \
# 0  {'age': 77, 'bachelors_field': 'no_degree', 'b...  PT-F02C4EE1
# 1  {'age': 21, 'bachelors_field': 'no_degree', 'b...  PT-063B2F07
# 2  {'age': 38, 'bachelors_field': 'no_degree', 'b...  PT-51DA2BB3
# 3  {'age': 32, 'bachelors_field': 'stem_related',...  PT-9243C94A
# 4  {'age': 29, 'bachelors_field': 'stem', 'birth_...  PT-8BEC23FF
#
#   symptom_onset_date date_of_visit first_name last_name         dob  \
# 0         2024-03-28    2024-04-06      Grace     White  1953-12-19
# 1         2024-03-27    2024-04-19    Katelyn    Rogers  1928-10-19
# 2         2024-07-02    2024-07-15      Tracy    Carter  1921-01-12
# 3         2024-07-09    2024-07-16    Charles     Burns  1941-10-20
# 4         2024-12-29    2025-01-05      Sarah  Mckinney  1986-07-21
#
#        physician                                    physician_notes
# 0  Dr. Zimmerman  **Patient:** Grace White
# **DOB:** 06/12/1978...
# 1    Dr. Burgess  **Visit Note - April 19, 2024**
# **Patient:**...
# 2   Dr. Buchanan  - 7/15/24: Tracy Carter, 32F, presents w/ hema...
# 3       Dr. Hall  **DR. CASSANDRA HALL – NEURO/IMMUNO REUMATOLOG...
# 4    Dr. Mcguire  **Progress Notes - Sarah Mckinney**
# **Date:*...

# %%
# Load the analysis results into memory.
analysis = results.load_analysis()

analysis.to_report()
# Out:
# ──────────────────────────────────────── 🎨 Data Designer Dataset Profile ─────────────────────────────────────────
#
#
#                                                  Dataset Overview
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ number of records               ┃ number of columns               ┃ percent complete records                    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 10                              │ 12                              │ 100.0%                                      │
# └─────────────────────────────────┴─────────────────────────────────┴─────────────────────────────────────────────┘
#
#
#                                               🌱 Seed-Dataset Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                          ┃               data type ┃                           number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ diagnosis                            │                  string │                                      7 (70.0%) │
# ├──────────────────────────────────────┼─────────────────────────┼────────────────────────────────────────────────┤
# │ patient_summary                      │                  string │                                    10 (100.0%) │
# └──────────────────────────────────────┴─────────────────────────┴────────────────────────────────────────────────┘
#
#
#                                                 🎲 Sampler Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                   ┃       data type ┃             number unique values ┃               sampler type ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ patient_sampler               │            dict │                      10 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ doctor_sampler                │            dict │                      10 (100.0%) │          person_from_faker │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ patient_id                    │          string │                      10 (100.0%) │                       uuid │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ symptom_onset_date            │          string │                      10 (100.0%) │                   datetime │
# ├───────────────────────────────┼─────────────────┼──────────────────────────────────┼────────────────────────────┤
# │ date_of_visit                 │          string │                      10 (100.0%) │                  timedelta │
# └───────────────────────────────┴─────────────────┴──────────────────────────────────┴────────────────────────────┘
#
#
#                                                 📝 LLM-Text Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                       ┃               ┃                            ┃     prompt tokens ┃      completion tokens ┃
# ┃ column name           ┃     data type ┃       number unique values ┃        per record ┃             per record ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ physician_notes       │        string │                10 (100.0%) │     119.5 +/- 6.0 │        968.5 +/- 402.6 │
# └───────────────────────┴───────────────┴────────────────────────────┴───────────────────┴────────────────────────┘
#
#
#                                                🧩 Expression Columns
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ column name                    ┃                 data type ┃                               number unique values ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ first_name                     │                    string │                                        10 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ last_name                      │                    string │                                        10 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ dob                            │                    string │                                        10 (100.0%) │
# ├────────────────────────────────┼───────────────────────────┼────────────────────────────────────────────────────┤
# │ physician                      │                    string │                                        10 (100.0%) │
# └────────────────────────────────┴───────────────────────────┴────────────────────────────────────────────────────┘
#
#
# ╭────────────────────────────────────────────────── Table Notes ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  1. All token statistics are based on a sample of max(1000, len(dataset)) records.                              │
# │  2. Tokens are calculated using tiktoken's cl100k_base tokenizer.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## ⏭️ Next Steps
#
# Check out the following notebook to learn more about:
#
# - [Providing images as context](https://nvidia-nemo.github.io/DataDesigner/latest/notebooks/4-providing-images-as-context/)
